# %%
import pandas as pd
import numpy as np
import math

df_vwc = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/s7vwc.csv', header = 0)[['Trend', 'signal.detrend', 'Noise']].T.to_numpy()
df_stemp = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/S7T.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
df_T = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/T.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
df_RH = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/RH.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
#df_DP = np.load('/content/drive/Shareddrives/1st Paper/Array_eemd2_DP.npy', allow_pickle=True)
df_Rain = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/R.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
df_WS = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/WS.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
#df_WD = np.load('/content/drive/Shareddrives/1st Paper/Array_eemd2_WD.npy', allow_pickle=True)
df_S = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/SR.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()

list_ = [df_vwc, df_Rain, df_stemp, df_T, df_RH,  df_WS, df_S]

# IMF = np.empty((10, 10, 10))
ssa = [[],[],[]]
# for i in list_:
#   print(i.shape)
for k in range(len(ssa)):
  for i in list_:
    ssa[k].append(i[k])


# df_vwc = pd.DataFrame(df_vwc).T
# df_vwc.columns = ['IMF1','IMF2','IMF3','IMF4','IMF5','IMF6','IMF7','IMF8','IMF9','IMF10','IMF11',
#               'IMF12','IMF13','IMF14', 'IMF15']

# df_stemp = pd.DataFrame(df_stemp).T
# df_stemp.columns = ['IMF1','IMF2','IMF3','IMF4','IMF5','IMF6','IMF7','IMF8','IMF9','IMF10','IMF11',
#               'IMF12','IMF13']

# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 7.5 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.4.47)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.2 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.0

# %%
##LSTM
import pandas as pd
import numpy as np
import math

import sklearn
import keras
import keras.backend as K
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM, CuDNNLSTM, MaxPooling1D, Conv1D, Flatten, BatchNormalization, Dropout, Input
from keras.models import Model
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping


from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from math import sqrt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from multiprocessing import cpu_count 
from joblib import Parallel 
from joblib import delayed 
from datetime import datetime

import optuna 

from sklearn.preprocessing import StandardScaler

from keras.utils import custom_object_scope
from keras.utils import get_custom_objects

from keras.layers import LSTM, RepeatVector, TimeDistributed, BatchNormalization, Dropout
from keras.initializers import GlorotUniform
from keras.activations import relu
from joblib import Parallel, delayed

import cProfile

# from warnings import catch_warnings 
# from warnings import filterwarnings

# %%
####################################################################################################
def nmse(y_true, y_pred):
    """
    Calculate the normalized mean squared error (NMSE) between y_true and y_pred.
    """
    return np.mean(np.square(y_pred - y_true)) / np.var(y_true)
####################################################################################################
def smape(y_true, y_pred):
    """
    Calculate the Symmetric Mean Absolute Percentage Error (SMAPE) between y_true and y_pred.
    """
    return np.mean(2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred))) * 100
####################################################################################################
def smase(y_true, y_pred, y_naive):
    """
    Calculate the Symmetric Mean Absolute Scaled Error (sMASE) between y_true and y_pred, relative 
    to a symmetric naive forecast y_naive.
    """
    # Calculate the symmetric naive forecast
    y_sym_naive = (y_naive.shift(1) + y_naive.shift(-1)) / 2.0
    
    # Calculate the MAPE of the forecast relative to the symmetric naive forecast
    mape_forecast = np.mean(np.abs(y_pred - y_sym_naive) / np.abs(y_true - y_sym_naive))
    
    # Calculate the MAPE of the historical data relative to the same symmetric naive forecast
    mape_historical = np.mean(np.abs(y_true - y_sym_naive.shift(1)) / np.abs(y_true - y_sym_naive))
    
    return mape_forecast / mape_historical
####################################################################################################
def nse(y_true, y_pred):
    """
    Calculate the Nash-Sutcliffe Efficiency (NSE) between y_true and y_pred.
    """
    mse = mean_squared_error(y_true, y_pred)
    rss = mse * len(y_true)
    tss = mean_absolute_error(y_true, np.mean(y_true)) ** 2 * len(y_true)
    return 1 - (rss / tss)
#####################################################################################################
def r2_keras(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# Register the custom metric function with Keras
with custom_object_scope({'r2_keras': r2_keras}):
    get_custom_objects().update({'r2_keras': r2_keras})

# %%
##Encoder/Decoder LSTM with Multivariate Input

#Splitting datasets into train/test set

def split_dataset(data):
  # split into standard weeks
  train, test = data[1:-6046], data[-6048:]
  #train, test = data[:-5817], data[-5817:-57]
  # restructure into windows of weekly data
  train = np.array(np.split(train, len(train)/144))
  test = np.array(np.split( test , len(test )/144))
  return train, test

def rmse_(actual, predicted):
    return np.sqrt(mean_squared_error(actual, predicted))

def nmse(actual, predicted):
    return mean_squared_error(actual, predicted) / np.var(actual)

def smape(actual, predicted):
    return 100 / len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted)))

def nse(actual, predicted):
    return 1 - np.sum((actual - predicted) ** 2) / np.sum((actual - np.mean(actual)) ** 2)

def r2(y_true, y_pred):
    SS_res =  np.sum(K.square(y_true - y_pred))
    SS_tot =  np.sum(K.square(y_true - np.mean(y_true)))
    return 1 - SS_res/(SS_tot + np.finfo(float).eps) 

def compute_scores(actual, predicted):
    rmse_score = rmse_(actual, predicted)
    nmse_score = nmse(actual, predicted)
    smape_score = smape(actual, predicted)
    nse_score = nse(actual, predicted)
    r2_score = r2(actual, predicted)
    return rmse_score, nmse_score, smape_score, nse_score, r2_score

def evaluate_forecasts(actual, predicted):
    # rmse_scores = [rmse_(actual[:, i],   predicted[:, i])      for i in  range(actual.shape[1])]
    # nmse_scores = [nmse(actual[:, i],    predicted[:, i])      for i in  range(actual.shape[1])]
    # smape_scores = [smape(actual[:, i],  predicted[:, i])      for i in  range(actual.shape[1])]
    # nse_scores = [nse(actual[:, i],      predicted[:, i])      for i in  range(actual.shape[1])]
    # r2_scores = [r2(actual[:,i],   predicted[:, i])      for i in  range(actual.shape[1])]
    # parallelize the loop using joblib

    rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores = zip(*Parallel(n_jobs=-1)(
    delayed(compute_scores)(actual[:, i], predicted[:, i]) for i in range(actual.shape[1])))

    overall_rmse = rmse_(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_nmse = nmse(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_smape = smape(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_nse = nse(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_r2 = r2(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    return overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores

#####################################################################################################
#summarize scores
def summarize_scores(name, score, scores):
  s_scores = ', '.join(['%.1f' % s for s in scores])
  print('%s: [%.3f] %s' % (name, score, s_scores))

# convert history into inputs and outputs


def to_supervised(train, n_input, n_out=144):
  #flattern data
  data = train.reshape((train.shape[0]*train.shape[1], train.shape[2]))
  X, y = list(), list()
  in_start = 0
  # step over the entire history one time step at a time
  for i in range(len(data)):
    #define the end of the input sequence
    in_end = in_start + n_input
    out_end = in_end + n_out
    #ensure there is enough data
    if out_end <= len(data):
      X.append(data[in_start:in_end, :])
      y.append(data[in_end:out_end, 0])
    # move along one time step
    in_start += 1
  return np.array(X), np.array(y)
 
# #train the model LSTM-ED

def build_model(train, config, verbose):
  # Unpack config
  n_input, n_nodes, n_epochs, n_batch = config
  # prepare data
  train_x, train_y = to_supervised(train, n_input)
  # Parameters
  n_timesteps, n_features, n_outputs = train_x.shape[1], train_x.shape[2], train_y.shape[1]
  # reshape output into [samples, timesteps, features]
  train_y = train_y.reshape((train_y.shape[0], train_y.shape[1], 1))
  
  #define model
  
  # define model input
  inputs = Input(shape=(n_timesteps, n_features))
  
  # encoder layers
  encoder = CuDNNLSTM(n_nodes)(inputs)
  encoder = RepeatVector(n_outputs)(encoder)
  
  # decoder layers
  decoder = CuDNNLSTM(n_nodes, return_sequences=True)(encoder)
  decoder = TimeDistributed(Dense(n_nodes/2))(decoder)
  decoder = TimeDistributed(Dense(1))(decoder)

  # define model
  model = Model(inputs=inputs, outputs=decoder)

  model.compile(loss='mae', optimizer='adam',  metrics= ['MeanAbsoluteError', 'MeanSquaredError', 'mean_absolute_percentage_error', 'r2_keras'])
  
  # fit network
  model.fit(train_x, train_y, epochs=n_epochs, batch_size=n_batch, verbose= verbose)
  plt.plot(model.history.history['loss'])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['loss'], loc='upper right')
  plt.show()
  plt.clf()
  plt.plot(model.history.history['mean_absolute_error'])
  plt.plot(model.history.history['mean_squared_error'])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['mean_absolute_error', 'mean_squared_error'], loc='upper right')
  plt.show()
  plt.clf()
  plt.plot(model.history.history['mean_absolute_percentage_error'])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['mean_absolute_percentage_error'], loc='upper right')
  plt.show()
  plt.clf()
  plt.plot(model.history.history['r2_keras'])
  #plt.plot(model.history.history[])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['r2_score'], loc='upper right')
  plt.show()
  return model

#forecast

def forecast(model, history, config):
  # unpack config
  n_input, _, _, _ = config
  #flattern data
  data = np.array(history)
  data = data.reshape((data.shape[0]*data.shape[1], data.shape[2]))
  #retrieve last observations for input data
  input_x = data[-n_input:, :]
  # reshape into [1, n_input, n]
  input_x = input_x.reshape((1, input_x.shape[0], input_x.shape[1]))
  #forecast the next week
  yhat = model.predict(input_x, verbose=0)
  # we only want the vector forecast
  yhat = yhat
  return yhat

#evaluate a single model

def evaluate_model(train, test, cfg, verbose):
  #fit model
  model= build_model(train, cfg, verbose)
  #test = X_scaler.transform(test)
  # history is a list of n_input data
  history = [x for x in train]
  #walk_forward validation over each week
  predictions = list()
  for i in range(len(test)):
    #predict the week
    yhat_sequence = forecast(model, history, cfg)[0]
    #store the predictions
    predictions.append(yhat_sequence)
    #get real observation an add to history for predicting the next week
    history.append(test[i, :])
  #evaluate predictions hours for each n_input
  predictions = np.array(predictions)
  #overall_rmse,overall_nmse, overall_smape, overall_nse, rmse_scores, nmse_scores, smape_scores, nse_scores
  overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores = evaluate_forecasts(test[:, :, 0], predictions)
  return overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores, predictions, model

#Repeat evaluate

def repeat_evaluate(train, test, config, verbose, n_repeats=2):
  # Convert config to a key
  key = str(config)
  # fit and evaluate the model n times
  overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores, predictions, model = evaluate_model(train, test, config, verbose)
  overall_rmse_models = [overall_rmse for _ in range(n_repeats)]
  overall_nmse_models = [overall_nmse for _ in range(n_repeats)]
  overall_smape_models = [overall_smape for _ in range(n_repeats)]
  overall_nse_models = [overall_nse for _ in range(n_repeats)]
  overall_r2_models = [overall_r2 for _ in range(n_repeats)]
  # Sumarize score
  result_rmse =  np.mean(overall_rmse_models)
  result_nmse =  np.mean(overall_nmse_models)
  result_smape = np.mean(overall_smape_models)
  result_nse =   np.mean(overall_nse_models)
  result_r2 =    np.mean(overall_r2_models)
  #print('> Model[%s] %.3f' % (key, result))
  return (key, result_rmse, result_nmse, result_smape, result_nse, result_r2), predictions

# grid_search configs

def grid_search(train, test, cfg_list, verbose):
  #evaluate configs
  pack = [repeat_evaluate(train, test, cfg, verbose) for cfg in cfg_list]
  #sort config by error, asc
  scores = [item[0] for item in pack]
  predictions = [item[1] for item in pack]
  scores.sort(key=lambda tup: tup[1])
  return scores, predictions


def model_configs():
  n_input = [200]
  n_nodes = [200]
  n_epochs = [250]
  n_batch = [10]
  configs = list()
  for i in n_input:
    for j in n_nodes:
      for k in n_epochs:
        for l in n_batch:
          cfg = [i, j, k , l]
          configs.append(cfg)
  print('Total configs: %d' % len(configs))
  return configs

# %%
# define the objective function
def objective(trial):

    # specify the hyperparameters to optimize
    n_input = trial.suggest_int('n_input', 1, 144)
    n_nodes = trial.suggest_int('n_nodes', 32, 256)
    n_epochs = trial.suggest_int('n_epochs', 10, 100)
    n_batch = trial.suggest_int('n_batch', 16, 128)
    
    # split the data into training and testing sets
    train, test = split_dataset(df_s.values)
    #train = df_s.values

    # split the training data into folds for walk-forward validation
    n_splits = 5
    fold_size = int(len(train) / n_splits)
    folds = [train[i:i+fold_size] for i in range(0, len(train), fold_size)]
    
    # build the model using the hyperparameters
    model = build_model(train, (n_input, n_nodes, n_epochs, n_batch), verbose=False)
    
    
    # train and evaluate the model using walk-forward validation
    val_losses = []
    for i in range(n_splits):
        # prepare data for this fold
        train_x, train_y = to_supervised(np.concatenate(folds[:i] + folds[i+1:]), n_input)
        val_x, val_y = to_supervised(folds[i], n_input)
        train_y = train_y.reshape((train_y.shape[0], train_y.shape[1], 1))
        val_y = val_y.reshape((val_y.shape[0], val_y.shape[1], 1))
        
        # train the model using early stopping
        es = EarlyStopping(monitor='val_loss', patience=3)
        history = model.fit(train_x, train_y, epochs=n_epochs, batch_size=n_batch, validation_data=(val_x, val_y), verbose=False, callbacks=[es])
        
        # evaluate the model on the validation set for this fold
        val_loss = history.history['val_loss'][-1]
        val_losses.append(val_loss)

        # metrics on validation set for this fold
        #al_mae = history.history['mean_absolute_error'][-1]
        #val_mse = history.history['mean_squared_error'][-1]
    
    # return the mean validation loss across all folds
    return np.mean(val_losses)

# %%
#Scores_IMF = []
dataset = pd.read_csv('/content/drive/Shareddrives/1st Paper/2nd.csv', header = 0, infer_datetime_format=True, index_col=['Date Time'])
#dataset = dataset[:-8438]
# set the base name of the file
base_filename = '/content/drive/Shareddrives/1st Paper/Performance/S7_best_model_ssa_VWC'

for m in range(0, 3):

  sc = ([0, 0, 0, 0], 0, 0, 0, 0, 0)
  print('IMF: ', m)
  data = pd.DataFrame(ssa[m]).T
  data.columns = ['S7_Top_VWC_Avg','Rain','S7_Top_Temp_Avg','Temp', 'Relative Humidity',
                 'Wind Speed', 'Solar Radiation']
  #testing = data[-8438:]
  #data = data[:-8438] 
  data = data

  # %time
  External = data[['Rain','S7_Top_Temp_Avg','Temp', 'Relative Humidity',
                 'Wind Speed', 'Solar Radiation']]
  Predicted = data[['S7_Top_VWC_Avg']]
  index = pd.DataFrame(dataset.index)
  
  scaler = StandardScaler()
  scaler.fit(External)
  print('Scale_:', scaler.scale_)
    
  var = pd.DataFrame(scaler.transform(External))

  #var = data
  df = pd.concat([index, data['S7_Top_VWC_Avg'], var], axis = 1)
  df = df.set_index('Date Time')
  df.columns = ['S7_Top_VWC_Avg','Rain','S7_Top_Temp_Avg','Temp', 'Relative Humidity',
                  'Wind Speed', 'Solar Radiation']
  df_s = df


  
  # create the study
  study = optuna.create_study(direction='minimize', storage='sqlite:///example.db')

  # start the optimization
  study.optimize(objective, n_trials=3)

  # retrieve the best hyperparameters
  best_params = study.best_params
  print('Best hyperparameters:', best_params)

  train, test = split_dataset(df.values)

  # train the model using the best hyperparameters on the entire training set
  model = build_model(train, (best_params['n_input'], best_params['n_nodes'], best_params['n_epochs'], best_params['n_batch']), verbose=True)

  # set the filename based on the unique identifier
  filename = f"{base_filename}_{m}.h5"

  # save the model to a file
  model.save(filename)
# Out:
# IMF:  0
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.82 µs
# Scale_: [0.05333779 0.52444927 0.59696625 0.90858732 0.94264763 0.89602207]
# [I 2023-03-31 02:35:48,799] A new study created in RDB with name: no-name-9b714c35-4aa7-4f11-814f-7d93e9031dd5
# [I 2023-03-31 02:45:28,906] Trial 0 finished with value: 0.07573082968592644 and parameters: {'n_input': 16, 'n_nodes': 211, 'n_epochs': 55, 'n_batch': 31}. Best is trial 0 with value: 0.07573082968592644.
# [I 2023-03-31 02:49:56,056] Trial 1 finished with value: 0.08604170233011246 and parameters: {'n_input': 29, 'n_nodes': 125, 'n_epochs': 27, 'n_batch': 39}. Best is trial 0 with value: 0.07573082968592644.
# [I 2023-03-31 02:57:10,242] Trial 2 finished with value: 0.024548629485070705 and parameters: {'n_input': 114, 'n_nodes': 146, 'n_epochs': 70, 'n_batch': 64}. Best is trial 2 with value: 0.024548629485070705.
# Best hyperparameters: {'n_batch': 64, 'n_epochs': 70, 'n_input': 114, 'n_nodes': 146}
# Epoch 1/70
# 280/280 [==============================] - 7s 17ms/step - loss: 0.1994 - mean_absolute_error: 0.1994 - mean_squared_error: 0.0803 - mean_absolute_percentage_error: 114.0335 - r2_keras: 0.9176
# Epoch 2/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.1583 - mean_absolute_error: 0.1583 - mean_squared_error: 0.0479 - mean_absolute_percentage_error: 93.8796 - r2_keras: 0.9497
# Epoch 3/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.1256 - mean_absolute_error: 0.1256 - mean_squared_error: 0.0314 - mean_absolute_percentage_error: 77.7335 - r2_keras: 0.9671
# Epoch 4/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.1000 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0209 - mean_absolute_percentage_error: 62.0454 - r2_keras: 0.9778
# Epoch 5/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0792 - mean_absolute_error: 0.0792 - mean_squared_error: 0.0134 - mean_absolute_percentage_error: 50.7159 - r2_keras: 0.9861
# Epoch 6/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0639 - mean_absolute_error: 0.0639 - mean_squared_error: 0.0087 - mean_absolute_percentage_error: 43.1484 - r2_keras: 0.9908
# Epoch 7/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0563 - mean_absolute_error: 0.0563 - mean_squared_error: 0.0069 - mean_absolute_percentage_error: 39.5831 - r2_keras: 0.9927
# Epoch 8/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0482 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0047 - mean_absolute_percentage_error: 34.4137 - r2_keras: 0.9951
# Epoch 9/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0399 - mean_absolute_error: 0.0399 - mean_squared_error: 0.0032 - mean_absolute_percentage_error: 27.1666 - r2_keras: 0.9966
# Epoch 10/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0362 - mean_absolute_error: 0.0362 - mean_squared_error: 0.0025 - mean_absolute_percentage_error: 24.2288 - r2_keras: 0.9974
# Epoch 11/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0342 - mean_absolute_error: 0.0342 - mean_squared_error: 0.0022 - mean_absolute_percentage_error: 22.2849 - r2_keras: 0.9977
# Epoch 12/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0395 - mean_absolute_error: 0.0395 - mean_squared_error: 0.0040 - mean_absolute_percentage_error: 23.4244 - r2_keras: 0.9959
# Epoch 13/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0296 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0017 - mean_absolute_percentage_error: 19.1414 - r2_keras: 0.9982
# Epoch 14/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0280 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0015 - mean_absolute_percentage_error: 18.2054 - r2_keras: 0.9985
# Epoch 15/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0296 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0018 - mean_absolute_percentage_error: 17.9377 - r2_keras: 0.9981
# Epoch 16/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0289 - mean_absolute_error: 0.0289 - mean_squared_error: 0.0017 - mean_absolute_percentage_error: 18.4703 - r2_keras: 0.9982
# Epoch 17/70
# 280/280 [==============================] - 6s 20ms/step - loss: 0.0250 - mean_absolute_error: 0.0250 - mean_squared_error: 0.0013 - mean_absolute_percentage_error: 15.8618 - r2_keras: 0.9987
# Epoch 18/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0243 - mean_absolute_error: 0.0243 - mean_squared_error: 0.0011 - mean_absolute_percentage_error: 15.2830 - r2_keras: 0.9989
# Epoch 19/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0220 - mean_absolute_error: 0.0220 - mean_squared_error: 8.7392e-04 - mean_absolute_percentage_error: 13.4961 - r2_keras: 0.9991
# Epoch 20/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0221 - mean_absolute_error: 0.0221 - mean_squared_error: 9.6737e-04 - mean_absolute_percentage_error: 13.1910 - r2_keras: 0.9990
# Epoch 21/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0209 - mean_absolute_error: 0.0209 - mean_squared_error: 8.0821e-04 - mean_absolute_percentage_error: 13.0778 - r2_keras: 0.9992
# Epoch 22/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0246 - mean_absolute_error: 0.0246 - mean_squared_error: 0.0016 - mean_absolute_percentage_error: 15.2102 - r2_keras: 0.9983
# Epoch 23/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0335 - mean_absolute_error: 0.0335 - mean_squared_error: 0.0040 - mean_absolute_percentage_error: 23.8834 - r2_keras: 0.9958
# Epoch 24/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0206 - mean_absolute_error: 0.0206 - mean_squared_error: 7.6881e-04 - mean_absolute_percentage_error: 12.7305 - r2_keras: 0.9992
# Epoch 25/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0210 - mean_absolute_error: 0.0210 - mean_squared_error: 0.0012 - mean_absolute_percentage_error: 13.1712 - r2_keras: 0.9988
# Epoch 26/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0185 - mean_absolute_error: 0.0185 - mean_squared_error: 6.1450e-04 - mean_absolute_percentage_error: 11.1964 - r2_keras: 0.9994
# Epoch 27/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0180 - mean_absolute_error: 0.0180 - mean_squared_error: 5.9213e-04 - mean_absolute_percentage_error: 10.8110 - r2_keras: 0.9994
# Epoch 28/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0222 - mean_absolute_error: 0.0222 - mean_squared_error: 0.0014 - mean_absolute_percentage_error: 13.5293 - r2_keras: 0.9986
# Epoch 29/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0452 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0075 - mean_absolute_percentage_error: 29.1130 - r2_keras: 0.9923
# Epoch 30/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0228 - mean_absolute_error: 0.0228 - mean_squared_error: 0.0014 - mean_absolute_percentage_error: 12.7262 - r2_keras: 0.9986
# Epoch 31/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0179 - mean_absolute_error: 0.0179 - mean_squared_error: 5.9815e-04 - mean_absolute_percentage_error: 10.4054 - r2_keras: 0.9994
# Epoch 32/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0177 - mean_absolute_error: 0.0177 - mean_squared_error: 5.8340e-04 - mean_absolute_percentage_error: 10.5905 - r2_keras: 0.9994
# Epoch 33/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0157 - mean_absolute_error: 0.0157 - mean_squared_error: 5.3301e-04 - mean_absolute_percentage_error: 9.6938 - r2_keras: 0.9994
# Epoch 34/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0163 - mean_absolute_error: 0.0163 - mean_squared_error: 4.8507e-04 - mean_absolute_percentage_error: 9.6943 - r2_keras: 0.9995
# Epoch 35/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0155 - mean_absolute_error: 0.0155 - mean_squared_error: 4.3721e-04 - mean_absolute_percentage_error: 9.5713 - r2_keras: 0.9995
# Epoch 36/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - mean_squared_error: 4.4964e-04 - mean_absolute_percentage_error: 9.4360 - r2_keras: 0.9995
# Epoch 37/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0146 - mean_absolute_error: 0.0146 - mean
70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.3462e-04 - mean_absolute_percentage_error: 6.9045 - r2_keras: 0.9998
# Epoch 64/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - mean_squared_error: 2.1682e-04 - mean_absolute_percentage_error: 6.2478 - r2_keras: 0.9998
# Epoch 65/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.0614e-04 - mean_absolute_percentage_error: 6.1674 - r2_keras: 0.9998
# Epoch 66/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.4665e-04 - mean_absolute_percentage_error: 6.3857 - r2_keras: 0.9997
# Epoch 67/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 1.8328e-04 - mean_absolute_percentage_error: 5.8520 - r2_keras: 0.9998
# Epoch 68/70
# 280/280 [==============================] - 5s 18ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.9134e-04 - mean_absolute_percentage_error: 6.0882 - r2_keras: 0.9998
# Epoch 69/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.8917e-04 - mean_absolute_percentage_error: 6.2393 - r2_keras: 0.9998
# Epoch 70/70
# 280/280 [==============================] - 5s 17ms/step - loss: 0.0098 - mean_absolute_error: 0.0098 - mean_squared_error: 1.7495e-04 - mean_absolute_percentage_error: 5.6927 - r2_keras: 0.9998
# IMF:  1
# [I 2023-03-31 03:03:40,910] A new study created in RDB with name: no-name-a5586cab-77d9-40dd-aa39-4a3964cf87d6
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs
# Scale_: [0.10577994 0.89500355 0.79257864 0.79027109 0.79057888 0.16606185]
# [I 2023-03-31 03:19:35,615] Trial 0 finished with value: 0.027684032917022705 and parameters: {'n_input': 83, 'n_nodes': 155, 'n_epochs': 97, 'n_batch': 28}. Best is trial 0 with value: 0.027684032917022705.
# [I 2023-03-31 03:26:07,512] Trial 1 finished with value: 0.07687081024050713 and parameters: {'n_input': 40, 'n_nodes': 173, 'n_epochs': 73, 'n_batch': 124}. Best is trial 0 with value: 0.027684032917022705.
# [I 2023-03-31 03:29:06,476] Trial 2 finished with value: 0.0749206081032753 and parameters: {'n_input': 75, 'n_nodes': 74, 'n_epochs': 22, 'n_batch': 60}. Best is trial 0 with value: 0.027684032917022705.
# Best hyperparameters: {'n_batch': 28, 'n_epochs': 97, 'n_input': 83, 'n_nodes': 155}
# Epoch 1/97
# 640/640 [==============================] - 13s 17ms/step - loss: 0.4014 - mean_absolute_error: 0.4014 - mean_squared_error: 0.2864 - mean_absolute_percentage_error: 336.5849 - r2_keras: 0.2890
# Epoch 2/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.2329 - mean_absolute_error: 0.2329 - mean_squared_error: 0.1046 - mean_absolute_percentage_error: 224.8315 - r2_keras: 0.7374
# Epoch 3/97
# 640/640 [==============================] - 10s 16ms/step - loss: 0.1781 - mean_absolute_error: 0.1781 - mean_squared_error: 0.0625 - mean_absolute_percentage_error: 193.3262 - r2_keras: 0.8428
# Epoch 4/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.1403 - mean_absolute_error: 0.1403 - mean_squared_error: 0.0400 - mean_absolute_percentage_error: 160.7858 - r2_keras: 0.8998
# Epoch 5/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.1108 - mean_absolute_error: 0.1108 - mean_squared_error: 0.0256 - mean_absolute_percentage_error: 134.1823 - r2_keras: 0.9359
# Epoch 6/97
# 640/640 [==============================] - 10s 16ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0166 - mean_absolute_percentage_error: 106.8001 - r2_keras: 0.9579
# Epoch 7/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0747 - mean_absolute_error: 0.0747 - mean_squared_error: 0.0115 - mean_absolute_percentage_error: 88.4462 - r2_keras: 0.9711
# Epoch 8/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0647 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0085 - mean_absolute_percentage_error: 71.9248 - r2_keras: 0.9785
# Epoch 9/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0560 - mean_absolute_error: 0.0560 - mean_squared_error: 0.0065 - mean_absolute_percentage_error: 58.2011 - r2_keras: 0.9839
# Epoch 10/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0495 - mean_absolute_error: 0.0495 - mean_squared_error: 0.0049 - mean_absolute_percentage_error: 51.4503 - r2_keras: 0.9878
# Epoch 11/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0042 - mean_absolute_percentage_error: 47.2173 - r2_keras: 0.9895
# Epoch 12/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0458 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0045 - mean_absolute_percentage_error: 52.6125 - r2_keras: 0.9887
# Epoch 13/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0389 - mean_absolute_error: 0.0389 - mean_squared_error: 0.0029 - mean_absolute_percentage_error: 40.3207 - r2_keras: 0.9926
# Epoch 14/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0364 - mean_absolute_error: 0.0364 - mean_squared_error: 0.0026 - mean_absolute_percentage_error: 35.9560 - r2_keras: 0.9936
# Epoch 15/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0348 - mean_absolute_error: 0.0348 - mean_squared_error: 0.0023 - mean_absolute_percentage_error: 34.4296 - r2_keras: 0.9942
# Epoch 16/97
# 640/640 [==============================] - 11s 17ms/step - loss: 0.0331 - mean_absolute_error: 0.0331 - mean_squared_error: 0.0022 - mean_absolute_percentage_error: 32.5387 - r2_keras: 0.9946
# Epoch 17/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0315 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0020 - mean_absolute_percentage_error: 31.3705 - r2_keras: 0.9951
# Epoch 18/97
# 640/640 [==============================] - 9s 13ms/step - loss: 0.0328 - mean_absolute_error: 0.0328 - mean_squared_error: 0.0025 - mean_absolute_percentage_error: 33.9118 - r2_keras: 0.9938
# Epoch 19/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0282 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - mean_absolute_percentage_error: 28.6980 - r2_keras: 0.9961
# Epoch 20/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0276 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0015 - mean_absolute_percentage_error: 27.7580 - r2_keras: 0.9963
# Epoch 21/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0290 - mean_absolute_error: 0.0290 - mean_squared_error: 0.0019 - mean_absolute_percentage_error: 28.7187 - r2_keras: 0.9951
# Epoch 22/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0266 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0015 - mean_absolute_percentage_error: 25.7202 - r2_keras: 0.9962
# Epoch 23/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0252 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0012 - mean_absolute_percentage_error: 24.1747 - r2_keras: 0.9969
# Epoch 24/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0236 - mean_absolute_error: 0.0236 - mean_squared_error: 0.0011 - mean_absolute_percentage_error: 23.1802 - r2_keras: 0.9972
# Epoch 25/97
# 640/640 [==============================] - 10s 16ms/step - loss: 0.0232 - mean_absolute_error: 0.0232 - mean_squared_error: 0.0011 - mean_absolute_percentage_error: 22.2877 - r2_keras: 0.9974
# Epoch 26/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0240 - mean_absolute_error: 0.0240 - mean_squared_error: 0.0011 - mean_absolute_percentage_error: 23.0570 - r2_keras: 0.9971
# Epoch 27/97
# 640/640 [==============================] - 10s 16ms/step - loss: 0.0234 - mean_absolute_error: 0.0234 - mean_squared_error: 0.0012 - mean_absolute_percentage_error: 22.6863 - r2_keras: 0.9970
# Epoch 28/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0214 - mean_absolute_error: 0.0214 - mean_squared_error: 9.0106e-04 - mean_absolute_percentage_error: 21.3054 - r2_keras: 0.9977
# Epoch 29/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0207 - mean_absolute_error: 0.0207 - mean_squared_error: 8.2767e-04 - mean_absolute_percentage_error: 19.9338 - r2_keras: 0.9979
# Epoch 30/97
# 640/640 [==============================] - 10s 16ms/step - loss: 0.0217 - mean_absolute_error: 0.0217 - mean_squared_error: 0.0011 - mean_absolute_percentage_error: 21.0109 - r2_keras: 0.9972
# Epoch 31/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0208 - mean_absolute_error: 0.0208 - mean_squared_error: 8.5649e-04 - mean_absolute_percentage_error: 20.1055 - r2_keras: 0.9979
# Epoch 32/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0187 - mean_absolute_error: 0.0187 - mean_squared_error: 6.8493e-04 - mean_absolute_percentage_error: 18.0929 - r2_keras: 0.9983
# Epoch 33/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0193 - mean_absolute_error: 0.0193 - mean_squared_error: 7.3386e-04 - mean_absolute_percentage_error: 18.5140 - r2_keras: 0.9982
# Epoch 34/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0188 - mean_absolute_error: 0.0188 - mean_squared_error: 6.9622e-04 - mean_absolute_percentage_error: 17.7393 - r2_keras: 0.9983
# Epoch 35/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0191 - mean_absolute_error: 0.0191 - mean_squared_error: 7.1958e-04 - mean_absolute_percentage_error: 18.6694 - r2_keras: 0.9982
# Epoch 36/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0178 - mean_absolute_error: 0.0178 - mean_squared_error: 6.3102e-04 - mean_absolute_percentage_error: 17.2470 - r2_keras: 0.9984
# Epoch 37/97
# 640/640 [==============================] - 10s 16ms/step - loss: 0.0178 - mean_absolute_error: 0.0178 - mean_squared_error: 6.5116e-04 - mean_absolute_percentage_error: 17.3737 - r2_keras: 0.9984
# Epoch 38/97
# 640/640 [==============================] - 10s 16ms/step - loss: 0.0178 - mean_absolute_error: 0.0178 - mean_squared_error: 6.3459e-04 - mean_absolute_percentage_error: 17.2490 - r2_keras: 0.9984
# Epoch 39/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0176 - mean_absolute_error: 0.0176 - mean_squared_error: 6.1942e-04 - mean_absolute_percentage_error: 16.6866 - r2_keras: 0.9985
# Epoch 40/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.
97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0133 - mean_absolute_error: 0.0133 - mean_squared_error: 4.0892e-04 - mean_absolute_percentage_error: 12.5875 - r2_keras: 0.9990
# Epoch 63/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - mean_squared_error: 2.8063e-04 - mean_absolute_percentage_error: 11.1136 - r2_keras: 0.9993
# Epoch 64/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - mean_squared_error: 3.2660e-04 - mean_absolute_percentage_error: 11.9456 - r2_keras: 0.9992
# Epoch 65/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - mean_squared_error: 3.2010e-04 - mean_absolute_percentage_error: 11.7290 - r2_keras: 0.9992
# Epoch 66/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - mean_squared_error: 2.9264e-04 - mean_absolute_percentage_error: 11.2617 - r2_keras: 0.9993
# Epoch 67/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - mean_squared_error: 3.2213e-04 - mean_absolute_percentage_error: 11.7787 - r2_keras: 0.9992
# Epoch 68/97
# 640/640 [==============================] - 8s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - mean_squared_error: 3.4302e-04 - mean_absolute_percentage_error: 11.8442 - r2_keras: 0.9992
# Epoch 69/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - mean_squared_error: 3.2103e-04 - mean_absolute_percentage_error: 11.8084 - r2_keras: 0.9992
# Epoch 70/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - mean_squared_error: 2.6979e-04 - mean_absolute_percentage_error: 11.0052 - r2_keras: 0.9993
# Epoch 71/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - mean_squared_error: 2.9738e-04 - mean_absolute_percentage_error: 11.4837 - r2_keras: 0.9993
# Epoch 72/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - mean_squared_error: 2.8381e-04 - mean_absolute_percentage_error: 11.0039 - r2_keras: 0.9993
# Epoch 73/97
# 640/640 [==============================] - 9s 13ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - mean_squared_error: 2.8559e-04 - mean_absolute_percentage_error: 10.9390 - r2_keras: 0.9993
# Epoch 74/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - mean_squared_error: 2.7745e-04 - mean_absolute_percentage_error: 11.1469 - r2_keras: 0.9993
# Epoch 75/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - mean_squared_error: 2.7653e-04 - mean_absolute_percentage_error: 10.7703 - r2_keras: 0.9993
# Epoch 76/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.5871e-04 - mean_absolute_percentage_error: 10.7479 - r2_keras: 0.9994
# Epoch 77/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - mean_squared_error: 2.6862e-04 - mean_absolute_percentage_error: 11.1366 - r2_keras: 0.9993
# Epoch 78/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.5491e-04 - mean_absolute_percentage_error: 10.6809 - r2_keras: 0.9994
# Epoch 79/97
# 640/640 [==============================] - 11s 17ms/step - loss: 0.0133 - mean_absolute_error: 0.0133 - mean_squared_error: 5.9843e-04 - mean_absolute_percentage_error: 12.6329 - r2_keras: 0.9985
# Epoch 80/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.4273e-04 - mean_absolute_percentage_error: 10.1961 - r2_keras: 0.9994
# Epoch 81/97
# 640/640 [==============================] - 9s 13ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.5689e-04 - mean_absolute_percentage_error: 10.5760 - r2_keras: 0.9994
# Epoch 82/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - mean_squared_error: 2.2669e-04 - mean_absolute_percentage_error: 9.9993 - r2_keras: 0.9994
# Epoch 83/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.7174e-04 - mean_absolute_percentage_error: 10.1099 - r2_keras: 0.9993
# Epoch 84/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - mean_squared_error: 2.3130e-04 - mean_absolute_percentage_error: 9.8654 - r2_keras: 0.9994
# Epoch 85/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.2710e-04 - mean_absolute_percentage_error: 9.8544 - r2_keras: 0.9994
# Epoch 86/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.2231e-04 - mean_absolute_percentage_error: 9.7343 - r2_keras: 0.9994
# Epoch 87/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.2193e-04 - mean_absolute_percentage_error: 9.6902 - r2_keras: 0.9994
# Epoch 88/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - mean_squared_error: 2.0970e-04 - mean_absolute_percentage_error: 9.7172 - r2_keras: 0.9995
# Epoch 89/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 2.2733e-04 - mean_absolute_percentage_error: 9.8287 - r2_keras: 0.9994
# Epoch 90/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.1316e-04 - mean_absolute_percentage_error: 9.5318 - r2_keras: 0.9995
# Epoch 91/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.3064e-04 - mean_absolute_percentage_error: 9.4835 - r2_keras: 0.9994
# Epoch 92/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 2.0174e-04 - mean_absolute_percentage_error: 9.3236 - r2_keras: 0.9995
# Epoch 93/97
# 640/640 [==============================] - 9s 15ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - mean_squared_error: 2.2010e-04 - mean_absolute_percentage_error: 9.5909 - r2_keras: 0.9994
# Epoch 94/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - mean_squared_error: 2.2159e-04 - mean_absolute_percentage_error: 9.7496 - r2_keras: 0.9994
# Epoch 95/97
# 640/640 [==============================] - 10s 15ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.1262e-04 - mean_absolute_percentage_error: 9.7769 - r2_keras: 0.9995
# Epoch 96/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 2.0411e-04 - mean_absolute_percentage_error: 9.3484 - r2_keras: 0.9995
# Epoch 97/97
# 640/640 [==============================] - 9s 14ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 6.0578e-04 - mean_absolute_percentage_error: 9.3743 - r2_keras: 0.9985
# IMF:  2
# [I 2023-03-31 03:44:31,951] A new study created in RDB with name: no-name-7c7a3232-b99b-4c98-b71f-a39748e689c1
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.44 µs
# Scale_: [0.99452068 0.02204783 0.0603335  0.74152791 0.73623446 0.45504398]
# [I 2023-03-31 03:54:44,944] Trial 0 finished with value: 0.7260606408119201 and parameters: {'n_input': 144, 'n_nodes': 225, 'n_epochs': 44, 'n_batch': 86}. Best is trial 0 with value: 0.7260606408119201.
# [I 2023-03-31 04:07:08,366] Trial 1 finished with value: 0.6809611678123474 and parameters: {'n_input': 76, 'n_nodes': 228, 'n_epochs': 82, 'n_batch': 74}. Best is trial 1 with value: 0.6809611678123474.
# [I 2023-03-31 04:17:49,902] Trial 2 finished with value: 0.617284506559372 and parameters: {'n_input': 71, 'n_nodes': 254, 'n_epochs': 77, 'n_batch': 64}. Best is trial 2 with value: 0.617284506559372.
# Best hyperparameters: {'n_batch': 64, 'n_epochs': 77, 'n_input': 71, 'n_nodes': 254}
# Epoch 1/77
# 281/281 [==============================] - 10s 23ms/step - loss: 1.6383 - mean_absolute_error: 1.6383 - mean_squared_error: 11.9595 - mean_absolute_percentage_error: 30.7088 - r2_keras: -0.0410
# Epoch 2/77
# 281/281 [==============================] - 6s 23ms/step - loss: 1.4580 - mean_absolute_error: 1.4580 - mean_squared_error: 11.3626 - mean_absolute_percentage_error: 26.9228 - r2_keras: 0.0099
# Epoch 3/77
# 281/281 [==============================] - 7s 23ms/step - loss: 1.3561 - mean_absolute_error: 1.3561 - mean_squared_error: 11.0459 - mean_absolute_percentage_error: 25.3694 - r2_keras: 0.0367
# Epoch 4/77
# 281/281 [==============================] - 6s 23ms/step - loss: 1