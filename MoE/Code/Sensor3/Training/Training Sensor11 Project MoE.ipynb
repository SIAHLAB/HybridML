# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 25.7 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.10.4-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 25.9 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.4 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import optuna

# %%
import pandas as pd
import numpy as np
import math

import sklearn
import keras
import keras.backend as K
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM, CuDNNLSTM, MaxPooling1D, Conv1D, Flatten, BatchNormalization, Dropout, Input
from keras.models import Model
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping


from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from math import sqrt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from multiprocessing import cpu_count 
from joblib import Parallel 
from joblib import delayed 
from datetime import datetime



from sklearn.preprocessing import StandardScaler

from keras.utils import custom_object_scope
from keras.utils import get_custom_objects
from keras.models import load_model

from keras.layers import LSTM, RepeatVector, TimeDistributed, BatchNormalization, Dropout
from tensorflow.keras.layers import Bidirectional
from keras.initializers import GlorotUniform
from keras.activations import relu
from joblib import Parallel, delayed

import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Dropout, TimeDistributed, Conv1D, MaxPooling1D, Flatten, LSTM, Multiply, Add
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow_probability as tfp
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import MultiHeadAttention
from tensorflow.keras.optimizers import SGD

# %%
s11 = pd.read_csv('/content/drive/Shareddrives/1st Paper/s11.csv', header = 0, infer_datetime_format=True, index_col=['TIMESTAMP']).drop('Unnamed: 0', axis=1).reset_index()
df = s11[[
       'S11_Top_Temp_Avg', 'S11_Top_VWC_Avg'
       
       ]]

# %%
def split_dataset(data):
  """
    Splits the dataset into train and test sets.
    
    Args:
        data (array): The dataset to be split.
        
    Returns:
        train (array): The training dataset.
        test (array): The testing dataset.
  """
  # split into standard weeks
  train, test = data[0:288], data[288:576]
  #train, test = data[:-5817], data[-5817:-57] 6048
  # restructure into windows of weekly data
  train = np.array(np.split(train, len(train)/144))
  test = np.array(np.split( test , len(test )/144))
  return train, test

def to_supervised(train, n_input):
    """
    Converts the input data into a supervised learning format.
    
    Args:
        train (array): The training dataset.
        n_input (int): The number of input time steps.
        
    Returns:
        X (array): The input features for supervised learning.
        y (array): The target values for supervised learning.
    """
    # Flatten data
    data = train.reshape((train.shape[0]*train.shape[1], train.shape[2]))
    X, y = list(), list()
    in_start = 0
    # Step over the entire history one time step at a time
    for _ in range(len(data)):
        # Define the end of the input sequence
        in_end = in_start + n_input
        out_end = in_end + 1
        # Ensure we have enough data for this instance
        if out_end < len(data):
            X.append(data[in_start:in_end, :])
            y.append(data[in_end, 0]) 
        # Move along one time step
        in_start += 1
    return np.array(X), np.array(y)

def build_moe_model_with_autoencoder_cnn_attention(input_dim, output_dim, expert_hidden_sizes, expert_output_sizes,
                                     gating_hidden_sizes, num_experts, learning_rate, activation, kernel_initializer, dropout_rate,
                                     num_iterations=100):
    """
    Builds a Mixture of Experts (MoE) model with autoencoder, CNN and attention mechanisms.
    
    Args:
        input_dim (int): The dimension of input features.
        output_dim (int): The dimension of output features.
        expert_hidden_sizes (list): The hidden layer sizes for each expert.
        expert_output_sizes (list): The output layer sizes for each expert.
        gating_hidden_sizes (list): The hidden layer sizes for the gating network.
        num_experts (int): The number of experts in the model.
        learning_rate (float): The learning rate for the optimizer.
        activation (str): The activation function to be used in the hidden layers.
        kernel_initializer (str): The kernel initializer for the layers.
        dropout_rate (float): The dropout rate for dropout layers.
        num_iterations (int, optional): The number of iterations for training. Defaults to 100.
        
    Returns:
        moe_model (Model): The Mixture of Experts model.
        experts (list): The list of expert models.
        gating_model (Model): The gating network model.
    """
    experts = []
    for i in range(num_experts):
        if i == 0:  # Replace first expert with an autoencoder
            expert_input = Input(shape=(input_dim))
            expert_hidden = Dense(expert_hidden_sizes[i], activation=activation, kernel_initializer=kernel_initializer)(expert_input)
            expert_hidden = Dropout(dropout_rate)(expert_hidden)
            expert_hidden = tf.expand_dims(expert_hidden, axis=1)  # Expand dimensions for LSTM input
            expert_hidden, _, _ = LSTM(expert_hidden_sizes[i], return_state=True, kernel_initializer='he_normal')(expert_hidden)
            attention = Dense(expert_hidden_sizes[i], activation='tanh', kernel_initializer='he_normal')(expert_hidden)
            attention = Dense(1, activation='softmax', kernel_initializer='he_normal')(attention)
            expert_hidden = Multiply()([expert_hidden, attention])
            expert_output = Dense(output_dim, activation='linear', kernel_initializer='he_normal')(expert_hidden)
            experts.append(Model(inputs=expert_input, outputs=expert_output))
        elif i == 1:  # Replace second expert with a Transformer expert
            expert_input = Input(shape=(input_dim))
            expert_hidden = Dense(expert_hidden_sizes[i], activation=activation, kernel_initializer=kernel_initializer)(expert_input)
            expert_hidden = Dropout(dropout_rate)(expert_hidden)
            expert_hidden = tf.expand_dims(expert_hidden, axis=1)  # Expand dimensions for Transformer input
            expert_hidden = MultiHeadAttention(num_heads=8, key_dim=expert_hidden_sizes[i])(expert_hidden, expert_hidden)
            expert_hidden = Flatten()(expert_hidden)
            attention = Dense(expert_hidden_sizes[i], activation='tanh', kernel_initializer='he_normal')(expert_hidden)
            attention = Dense(1, activation='softmax', kernel_initializer='he_normal')(attention)
            expert_hidden = Multiply()([expert_hidden, attention])
            expert_output = Dense(output_dim, activation='linear', kernel_initializer='he_normal')(expert_hidden)
            experts.append(Model(inputs=expert_input, outputs=expert_output))
        else:  # Replace third expert with a GRU-based model
            expert_input = Input(shape=(input_dim))
            expert_hidden = Dense(expert_hidden_sizes[i], activation=activation, kernel_initializer=kernel_initializer)(expert_input)
            expert_hidden = Dropout(dropout_rate)(expert_hidden)
            expert_hidden = tf.expand_dims(expert_hidden, axis=1)  # Expand dimensions for GRU input
            expert_hidden, _ = GRU(expert_hidden_sizes[i], return_state=True, kernel_initializer='he_normal')(expert_hidden)
            attention = Dense(expert_hidden_sizes[i], activation='tanh', kernel_initializer='he_normal')(expert_hidden)
            attention = Dense(1, activation='softmax', kernel_initializer='he_normal')(attention)
            expert_hidden = Multiply()([expert_hidden, attention])
            expert_output = Dense(output_dim, activation='linear', kernel_initializer='he_normal')(expert_hidden)
            experts.append(Model(inputs=expert_input, outputs=expert_output))

    # Define the gating network
    gating_input = Input(shape=(input_dim,))
    gating_hidden = Dense(gating_hidden_sizes[0], activation='relu', kernel_initializer='he_normal')(gating_input)
    gating_hidden = Dropout(dropout_rate)(gating_hidden)
    gating_hidden = tf.expand_dims(gating_hidden, axis=1)  # Expand dimensions for LSTM input
    gating_hidden = Bidirectional(LSTM(gating_hidden_sizes[1], return_sequences=False, kernel_initializer='he_normal'))(gating_hidden)

    gating_output = Dense(num_experts + num_experts * 2, activation=None, kernel_initializer='he_normal')(gating_hidden)
    logits = gating_output[:, :num_experts]
    params = gating_output[:, num_experts:]
    params = tf.reshape(params, [-1, num_experts, 2])

    gating_distribution = tfp.distributions.MixtureSameFamily(
        mixture_distribution=tfp.distributions.Categorical(logits=logits),
        components_distribution=tfp.distributions.Normal(
            loc=params[..., 0],
            scale=tf.math.softplus(params[..., 1])
        )
    )

    gating_model = Model(inputs=gating_input, outputs=logits)

    # Define the MoE model
    inputs = Input(shape=(input_dim,))
    outputs = []
    for i in range(num_experts):
        expert_output = experts[i](inputs)
        if i == 0:  # For the autoencoder expert, append encoded representation to outputs list
            outputs.append(expert_output)
        else:
            outputs.append(experts[i](inputs))

    gating_output = gating_model(inputs)
    weighted_outputs = [tf.expand_dims(gating_output[:, i], axis=-1) * expert_output[:, :1] for i, expert_output in enumerate(outputs)]

    outputs = tf.reduce_sum(weighted_outputs, axis=0)

    moe_model = Model(inputs=inputs, outputs=outputs)

    return moe_model, experts, gating_model

# Define the loss function
def moe_loss(y_true, y_pred, gating_output):
    """
    Defines the loss function for the Mixture of Experts (MoE) model.
    
    Args:
        y_true (tensor): The true target values.
        y_pred (tensor): The predicted target values.
        gating_output (tensor): The output of the gating network.
        
    Returns:
        (tensor): The calculated MoE loss.
    """
    y_true = tf.cast(y_true, y_pred.dtype)
    expert_losses = tf.reduce_mean(tf.square(y_true - y_pred), axis=-1)
    expert_losses = tf.expand_dims(expert_losses, axis=-1)
    
    # Apply softmax to the logits to get probabilities
    gating_probabilities = tf.nn.softmax(gating_output, axis=-1)
    
    # Multiply expert_losses with the gating probabilities instead of logits
    gating_losses = tf.reduce_sum(tf.multiply(expert_losses, gating_probabilities), axis=-1)
    return tf.reduce_mean(gating_losses)

def scheduler(epoch, lr):
    """
    Custom learning rate scheduler.
    
    Args:
        epoch (int): The current epoch.
        lr (float): The current learning rate.
        
    Returns:
        (float): The updated learning rate.
    """
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

def sliding_window_split(data, window_size, step_size):
    """
    Splits the input data into sliding windows of specified size and step size.
    
    Args:
        data (array): The input data to be split.
        window_size (int): The size of the sliding window.
        step_size (int): The step size for sliding the window.
        
    Returns:
        windowed_data (list): A list of arrays containing the data split into sliding windows.
    """
    windowed_data = []
    for i in range(0, len(data) - window_size, step_size):
        windowed_data.append(data[i:i + window_size])
    return windowed_data

def save_best_model_callback(study, trial):
    if study.best_trial.number == trial.number:
        # Save the best model
        best_model = trial.user_attrs['model']
        model_path = f'/content/drive/Shareddrives/1st Paper/best_MoE_model_s11_{trial.number}.h5'
        best_model.save(model_path)
        print(f"Best model saved to {model_path}")

# %%
def objective(trial, train_input, train_output, input_dim, output_dim):
    # Define the hyperparameters to optimize using Optuna
    dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.5)
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
    activation = trial.suggest_categorical('activation', ['relu', 'sigmoid', 'tanh'])
    kernel_initializer = trial.suggest_categorical('kernel_initializer', ['glorot_normal', 'he_normal', None])

    window_size = 500
    step_size = 50

    # Define the sizes of the hidden layers for each expert
    expert_hidden_sizes = [16, 32, 64]

    # Define the sizes of the output layers for each expert
    expert_output_sizes = [144,144,144]

    # Define the sizes of the gating network hidden layers
    gating_hidden_sizes = [16, 8]

    # Define the size of the output layer of the gating network
    gating_output_size = num_experts

    # Define the number of training iterations for the EM algorithm
    num_iterations = 10

    # Load the training data
    train_data = np.array(df.head(10000))


    # Split the training data into input and output sequences
    train_input = train_data[:, :]
    print('train_input shape', train_input.shape)
    train_output = train_data[:, -1:]
    print('train_output shape', train_output.shape)


    # Normalize input data
    train_input = (train_input - np.mean(train_input, axis=0)) / np.std(train_input, axis=0)


    train_input_windows = sliding_window_split(train_input, window_size, step_size)
    train_output_windows = sliding_window_split(train_output, window_size, step_size)

    # Build and train the model using the hyperparameters
    moe_model, experts, gating_model = build_moe_model_with_autoencoder_cnn_attention(
        input_dim,
        output_dim,
        expert_hidden_sizes,
        expert_output_sizes,
        gating_hidden_sizes,
        num_experts,
        learning_rate,
        activation,
        kernel_initializer,
        dropout_rate)

    # Define the optimization algorithm
    optimizer = Adam(learning_rate=learning_rate)

    # Learning rate scheduler
    lr_scheduler = LearningRateScheduler(scheduler)

    # Train the MoE model with the EM algorithm
    iteration = 0
    while iteration < num_iterations:
        num_train_windows = int(0.8 * len(train_input_windows))
        for window_idx in range(len(train_input_windows)):

          # E step: Compute the responsibilities of each expert for each data point
          gating_output = tf.constant(gating_model.predict(train_input), dtype=tf.float64)
          gating_output /= tf.reduce_sum(gating_output, axis=-1, keepdims=True) + 1e-8  # Add a small epsilon value

          # M step: Update the parameters of each expert and the gating network
          for i in range(num_experts):
              expert_input = train_input
              expert_output = experts[i](expert_input)
              expert_loss = tf.reduce_mean(tf.square(train_output - expert_output), axis=-1)

              with tf.GradientTape() as tape:
                  # Watch the trainable variables of the expert model
                  tape.watch(experts[i].trainable_variables)

                  # Define the expert model and calculate the expert_loss
                  expert_output = experts[i](expert_input)
                  expert_loss = tf.reduce_mean(tf.square(train_output - expert_output), axis=-1)

              # Compute the gradients
              expert_gradient = tape.gradient(expert_loss, experts[i].trainable_variables)
              # Clip gradients for expert models
              expert_gradient = [tf.clip_by_value(grad, -1.0, 1.0) for grad in expert_gradient]

              # Update the variables
              optimizer.apply_gradients(zip(expert_gradient, experts[i].trainable_variables))
          
          current_learning_rate = scheduler(iteration, optimizer.learning_rate.numpy())
          optimizer.learning_rate.assign(current_learning_rate)

          gating_input = train_input

          with tf.GradientTape() as tape:
              # Watch the trainable variables of the gating model
              tape.watch(gating_model.trainable_variables)

              # Define the gating model and calculate the gating_loss
              gating_output = gating_model(gating_input)
              gating_loss = moe_loss(tf.constant(train_output, dtype=tf.float32), moe_model(train_input), gating_output)


          # Compute the gradients
          gating_gradient = tape.gradient(gating_loss, gating_model.trainable_variables)
          # Clip gradients for the gating model
          gating_gradient = [tf.clip_by_value(grad, -1.0, 1.0) for grad in gating_gradient]

          # Update the variables
          optimizer.apply_gradients(zip(gating_gradient, gating_model.trainable_variables))

          # Evaluate the performance of the MoE model on the training set
          if window_idx < num_train_windows:
            train_loss = moe_loss(train_output_windows[window_idx], moe_model.predict(train_input_windows[window_idx]), gating_model.predict(train_input_windows[window_idx]))
            print(f'Iteration {iteration + 1}, Training window {window_idx + 1}: Training loss = {train_loss:.6f}')
          else:
            val_loss = moe_loss(train_output_windows[window_idx], moe_model.predict(train_input_windows[window_idx]), gating_model.predict(train_input_windows[window_idx]))
            print(f'Iteration {iteration + 1}, Validation window {window_idx - num_train_windows + 1}: Validation loss = {val_loss:.6f}')

        # Stop training if the learning rate becomes too small
        if current_learning_rate < 1e-6:
            print('Learning rate dropped below 1e-6 after iteration %d' % iteration)
            break

        iteration += 1
    trial.set_user_attr('model', moe_model)
    return train_loss

# %%
from functools import partial

# Load the training data
train_data = np.array(df.head(10000))


# Split the training data into input and output sequences
train_input = train_data[:, :]
print('train_input shape', train_input.shape)
train_output = train_data[:, -1:]
print('train_output shape', train_output.shape)


# Normalize input data
train_input = (train_input - np.mean(train_input, axis=0)) / np.std(train_input, axis=0)

input_dim = df.shape[1]
output_dim = 1

# Define the number of experts
num_experts = 3
objective_with_args = partial(objective, train_input=train_input, train_output=train_output, input_dim=input_dim, output_dim=output_dim)
study = optuna.create_study(direction="minimize")
study.optimize(objective_with_args, n_trials=5, callbacks=[save_best_model_callback])
# Out:
# [I 2023-05-12 12:56:49,306] A new study created in memory with name: no-name-66e50b1e-24d0-4e17-8f57-1cfe1f389865
# train_input shape (10000, 2)
# train_output shape (10000, 1)
# train_input shape (10000, 2)
# train_output shape (10000, 1)
# <ipython-input-6-5fdfc2a2915e>:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.5)
# <ipython-input-6-5fdfc2a2915e>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# Streaming output truncated to the last 5000 lines.
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 81: Training loss = 66.350151
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 82: Training loss = 45.340187
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 83: Training loss = 33.682926
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 84: Training loss = 24.546421
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 85: Training loss = 6.892596
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 86: Training loss = 6.776852
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 87: Training loss = 6.568833
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 88: Training loss = 6.465074
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 89: Training loss = 6.282704
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 90: Training loss = 6.727597
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 91: Training loss = 6.515150
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 92: Training loss = 6.605151
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 93: Training loss = 6.467453
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 94: Training loss = 6.141469
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 95: Training loss = 5.945978
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 96: Training loss = 5.513480
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 97: Training loss = 18.061993
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 98: Training loss = 18.086470
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 99: Training loss = 18.062716
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 100: Training loss = 17.258600
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 101: Training loss = 16.804625
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 102: Training loss = 16.182856
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 103: Training loss = 16.214493
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 104: Training loss = 16.294523
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 105: Training loss = 16.248604
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 106: Training loss = 16.243578
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 107: Training loss = 8.479734
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 108: Training loss = 10.852056
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 109: Training loss = 11.506267
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 110: Training loss = 17.984482
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 111: Training loss = 20.779325
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 112: Training loss = 23.001410
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 113: Training loss = 22.876139
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 114: Training loss = 25.690067
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 115: Training loss = 26.741787
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 116: Training loss = 27.113169
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 117: Training loss = 22.679667
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 118: Training loss = 20.085175
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 119: Training loss = 19.305342
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 120: Training loss = 12.985059
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 121: Training loss = 10.543075
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 122: Training loss = 8.424472
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 123: Training loss = 8.436292
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 124: Training loss = 5.626362
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 125: Training loss = 4.709327
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 126: Training loss = 4.582449
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 127: Training loss = 4.401929
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 128: Training loss = 4.189754
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 129: Training loss = 3.957314
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 130: Training loss = 3.976681
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 131: Training loss = 3.484816
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 132: Training loss = 3.118996
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 133: Training loss = 2.848583
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 134: Training loss = 2.561302
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 135: Training loss = 2.249115
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 136: Training loss = 1.788331
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 137: Training loss = 1.454553
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 138: Training loss = 1.155635
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 139: Training loss = 0.774818
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 140: Training loss = 0.360836
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 141: Training loss = 0.357791
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 142: Training loss = 0.354958
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 143: Training loss = 6.647510
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 144: Training loss = 7.784954
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 145: Training loss = 8.640725
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 146: Training loss = 8.973522
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 147: Training loss = 9.634231
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 148: Training loss = 9.835648
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 149: Training loss = 10.089185
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 150: Training loss = 11.970121
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 151: Training loss = 12.082363
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Training window 152: Training loss = 12.219642
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 1: Validation loss = 6.217413
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 2: Validation loss = 5.276379
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 3: Validation loss = 4.565142
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 4: Validation loss = 4.297863
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 5: Validation loss = 3.847496
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 6: Validation loss = 3.837040
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 7: Validation loss = 4.025959
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 8: Validation loss = 2.364946
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 9: Validation loss = 2.455085
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 10: Validation loss = 2.551374
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 11: Validation loss = 2.635603
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 12: Validation loss = 2.998843
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 13: Validation loss = 4.355973
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 14: Validation loss = 4.283463
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 15: Validation loss = 5.610487
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 16: Validation loss = 7.115602
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 17: Validation loss = 6.800234
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 18: Validation loss = 6.713727
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 19: Validation loss = 6.538700
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 20: Validation loss = 6.447930
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 21: Validation loss = 6.352809
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 22: Validation loss = 5.983034
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 23: Validation loss = 4.699646
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 24: Validation loss = 4.826159
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 25: Validation loss = 3.452707
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 26: Validation loss = 1.929130
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 27: Validation loss = 4.390363
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 28: Validation loss = 31.075930
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 29: Validation loss = 52.234509
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 30: Validation loss = 55.938660
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 31: Validation loss = 61.726669
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 32: Validation loss = 61.516956
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 33: Validation loss = 62.458748
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 34: Validation loss = 64.394157
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 35: Validation loss = 65.342476
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 36: Validation loss = 66.001434
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 37: Validation loss = 63.854252
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 4, Validation window 38: Validation loss = 37.701885
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 1: Training loss = 35.234436
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 2: Training loss = 35.130287
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 3: Training loss = 36.069473
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 4: Training loss = 35.559402
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 5: Training loss = 35.113621
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 6: Training loss = 34.900520
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 7: Training loss = 34.517235
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 8: Training loss = 34.409462
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 9: Training loss = 24.091635
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 10: Training loss = 4.250986
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 11: Training loss = 3.932088
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 12: Training loss = 3.460897
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 13: Training loss = 2.522991
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 14: Training loss = 2.585365
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 15: Training loss = 2.556992
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 16: Training loss = 2.645550
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 17: Training loss = 2.594791
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 18: Training loss = 2.549835
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 19: Training loss = 2.193053
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 20: Training loss = 2.198427
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 21: Training loss = 2.455805
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 22: Training loss = 3.478753
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 23: Training loss = 4.197955
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 24: Training loss = 4.624189
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 25: Training loss = 4.660733
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 26: Training loss = 4.555225
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 27: Training loss = 4.451864
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 28: Training loss = 4.612278
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 29: Training loss = 4.808915
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 30: Training loss = 4.743359
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 31: Training loss = 4.410307
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 32: Training loss = 3.973041
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 33: Training loss = 3.464607
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 34: Training loss = 4.029798
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 35: Training loss = 3.916940
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 36: Training loss = 3.854327
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 37: Training loss = 3.758723
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 38: Training loss = 3.540804
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 39: Training loss = 3.501016
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 40: Training loss = 3.580066
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 41: Training loss = 3.569866
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 42: Training loss = 28.277731
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 43: Training loss = 31.183601
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 44: Training loss = 29.901667
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 45: Training loss = 29.866526
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 46: Training loss = 29.973646
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 47: Training loss = 30.160349
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 48: Training loss = 30.141001
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 49: Training loss = 29.878689
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 50: Training loss = 29.661909
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 51: Training loss = 29.611061
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 52: Training loss = 4.837375
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 53: Training loss = 1.763991
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 54: Training loss = 1.806234
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 55: Training loss = 1.812053
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 56: Training loss = 1.696695
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 57: Training loss = 1.568674
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 58: Training loss = 1.534682
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 59: Training loss = 1.542978
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 60: Training loss = 1.585580
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 61: Training loss = 1.544188
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 62: Training loss = 1.573075
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 63: Training loss = 1.727449
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 64: Training loss = 1.820781
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 65: Training loss = 1.948278
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 66: Training loss = 1.906946
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 67: Training loss = 1.852538
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 68: Training loss = 1.872273
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 69: Training loss = 1.884394
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 70: Training loss = 1.986720
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 71: Training loss = 2.122663
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 72: Training loss = 19.440273
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 73: Training loss = 27.334846
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 74: Training loss = 34.131702
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 75: Training loss = 46.410385
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 76: Training loss = 46.752834
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 77: Training loss = 47.038021
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 78: Training loss = 47.457329
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 79: Training loss = 47.965759
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 80: Training loss = 48.246193
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 81: Training loss = 48.634438
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 82: Training loss = 31.934793
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 83: Training loss = 24.122778
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 84: Training loss = 17.479843
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 85: Training loss = 5.236633
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 86: Training loss = 5.176710
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 87: Training loss = 5.048012
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 88: Training loss = 4.988245
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 89: Training loss = 4.849072
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 90: Training loss = 4.992169
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 91: Training loss = 4.820159
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 92: Training loss = 4.907482
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 93: Training loss = 4.757192
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 94: Training loss = 4.477344
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 95: Training loss = 4.447202
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 96: Training loss = 4.069635
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 97: Training loss = 11.547340
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 98: Training loss = 11.566132
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 99: Training loss = 11.559812
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 100: Training loss = 11.110577
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 101: Training loss = 10.698932
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 102: Training loss = 10.181488
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 5, Training window 103: Training loss = 10.224387
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# ...
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 120: Training loss = 0.035493
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 121: Training loss = 0.025001
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 122: Training loss = 0.078190
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 123: Training loss = 0.023648
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 124: Training loss = 0.007435
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 125: Training loss = 0.019040
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 126: Training loss = 0.009741
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 127: Training loss = 0.004083
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 128: Training loss = 0.021586
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 129: Training loss = 0.010401
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 130: Training loss = 0.005202
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 131: Training loss = 0.021526
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 132: Training loss = 0.008443
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 133: Training loss = 0.004055
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 134: Training loss = 0.016766
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 135: Training loss = 0.006875
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 136: Training loss = 0.003975
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 137: Training loss = 0.023614
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 138: Training loss = 0.013832
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 139: Training loss = 0.001050
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 140: Training loss = 0.017915
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 141: Training loss = 0.006488
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 142: Training loss = 0.006750
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 143: Training loss = 0.045253
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 144: Training loss = 0.016305
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 145: Training loss = 0.018682
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 146: Training loss = 0.063277
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 147: Training loss = 0.021209
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 148: Training loss = 0.010915
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 149: Training loss = 0.052105
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 150: Training loss = 0.024676
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 151: Training loss = 0.028826
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Training window 152: Training loss = 0.091629
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 1: Validation loss = 0.026748
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 2: Validation loss = 0.012068
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 3: Validation loss = 0.045261
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 4: Validation loss = 0.017442
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 5: Validation loss = 0.015017
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 6: Validation loss = 0.048457
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 7: Validation loss = 0.020651
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 8: Validation loss = 0.006458
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 9: Validation loss = 0.027305
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 10: Validation loss = 0.015412
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 11: Validation loss = 0.005716
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 12: Validation loss = 0.028301
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 13: Validation loss = 0.014730
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 14: Validation loss = 0.011912
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 15: Validation loss = 0.051828
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 16: Validation loss = 0.027583
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 17: Validation loss = 0.011615
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 18: Validation loss = 0.048267
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 19: Validation loss = 0.019588
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 20: Validation loss = 0.016136
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 21: Validation loss = 0.059772
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 22: Validation loss = 0.024583
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 23: Validation loss = 0.011648
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 24: Validation loss = 0.039955
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 25: Validation loss = 0.011636
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 26: Validation loss = 0.009922
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 27: Validation loss = 0.059361
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 28: Validation loss = 0.042978
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 29: Validation loss = 0.112205
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 30: Validation loss = 0.316220
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 31: Validation loss = 0.074761
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 32: Validation loss = 0.112092
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 33: Validation loss = 0.343725
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 34: Validation loss = 0.084888
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 35: Validation loss = 0.152284
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 36: Validation loss = 0.401830
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 37: Validation loss = 0.092206
# 313/313 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step
# 16/16 [==============================] - 0s 2ms/step
# Iteration 10, Validation window 38: Validation loss = 0.068141
# [I 2023-05-12 15:59:15,647] Trial 4 finished with value: 0.0916294977068901 and parameters: {'dropout_rate': 0.0138342270242367, 'learning_rate': 0.002670222907058842, 'activation': 'relu', 'kernel_initializer': None}. Best is trial 1 with value: 0.0289488323032856.

# %%
moe_model = load_model('/content/drive/Shareddrives/1st Paper/best_MoE_model_s11_0.h5')

# Load the test data
test_data = np.array(df[10000:12000])

# Split the test data into input and output sequences
test_input = test_data[:, :]
test_output = test_data[:, -1:]

# Normalize the input data (use the same normalization parameters as the training set)
test_input = (test_input - np.mean(train_input, axis=0)) / np.std(train_input, axis=0)

test_predictions = moe_model.predict(test_input)

mae = mean_absolute_error(test_output, test_predictions)
mse = mean_squared_error(test_output, test_predictions)
print(f"Model performance on test set: MAE={mae}, MSE={mse}")

import matplotlib.pyplot as plt

# Set the font size for both the legend and axis numbers
legend_font_size = 24
axis_font_size = 24

# Create a new figure object with a larger size and a higher DPI for better quality
fig = plt.figure(figsize=(15, 8), dpi=100)

# Create your plot within the new figure object
plt.plot(test_predictions , color = 'blue', label='Predictions', linestyle='--')
plt.plot(test_output, color = 'red', label='Actual Output')

# Add a legend to the plot with a larger font size
plt.legend(fontsize=legend_font_size)

# Increase the font size of the axis numbers
plt.xticks(fontsize=axis_font_size)
plt.yticks(fontsize=axis_font_size)

# Add labels to the axes with a larger font size
plt.xlabel('Timesteps', fontsize=axis_font_size)
plt.ylabel('Value', fontsize=axis_font_size)

# Display the plot
plt.show()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 63/63 [==============================] - 1s 3ms/step
# Model performance on test set: MAE=10.541634221540605, MSE=123.18075542942276

# %%
study.best_params
# Out:
# {'dropout_rate': 0.2289625060750154,
#  'learning_rate': 0.0008599429411664891,
#  'activation': 'sigmoid',
#  'kernel_initializer': 'glorot_normal'}

# %%
# retrieve the best hyperparameters
best_params = {'dropout_rate': 0.2289625060750154,
 'learning_rate': 0.0008599429411664891,
 'activation': 'sigmoid',
 'kernel_initializer': 'glorot_normal'}

# Train the model with the best hyperparameters


# Load the training data
train_data = np.array(df.head(10000))


# Split the training data into input and output sequences
train_input = train_data[:, :]
print('train_input shape', train_input.shape)
train_output = train_data[:, -1:]
print('train_output shape', train_output.shape)

# Define the input and output dimensions
input_dim = df.shape[1]
output_dim = 1

# Define the number of experts
num_experts = 3

# Define the sizes of the hidden layers for each expert
expert_hidden_sizes = [16, 32, 64]

# Define the sizes of the output layers for each expert
expert_output_sizes = [144,144,144]

# Define the sizes of the gating network hidden layers
gating_hidden_sizes = [16, 8]

# Define the size of the output layer of the gating network
gating_output_size = num_experts

# Define the number of training iterations for the EM algorithm
num_iterations = 300

# Define the optimization algorithm
optimizer = SGD(learning_rate=best_params["learning_rate"], momentum=0.9, nesterov=True)

# Learning rate scheduler
lr_scheduler = LearningRateScheduler(scheduler)


moe_model, experts, gating_model = build_moe_model_with_autoencoder_cnn_attention(
    input_dim,
    output_dim,
    expert_hidden_sizes,
    expert_output_sizes,
    gating_hidden_sizes,
    num_experts,
    best_params["learning_rate"],
    best_params["activation"],
    best_params["kernel_initializer"],
    best_params["dropout_rate"])


all_trainable_variables = []
for expert in experts:
    all_trainable_variables.extend(expert.trainable_variables)
all_trainable_variables.extend(gating_model.trainable_variables)
optimizer.build(all_trainable_variables)

# Initialize variables to keep track of the lowest loss and corresponding weights
lowest_loss = float('inf')
best_weights = None

# create an empty list to store the loss values
losses = []
iterations = []

# Train the MoE model with the EM algorithm
iteration = 0
while iteration < num_iterations:

    # E step: Compute the responsibilities of each expert for each data point
    gating_output = tf.constant(gating_model.predict(train_input), dtype=tf.float64)
    gating_output /= tf.reduce_sum(gating_output, axis=-1, keepdims=True) + 1e-8  # Add a small epsilon value

    # M step: Update the parameters of each expert and the gating network
    for i in range(num_experts):
        expert_input = train_input
        expert_output = experts[i](expert_input)
        expert_loss = tf.reduce_mean(tf.square(train_output - expert_output), axis=-1)

        with tf.GradientTape() as tape:
            # Watch the trainable variables of the expert model
            tape.watch(experts[i].trainable_variables)

            # Define the expert model and calculate the expert_loss
            expert_output = experts[i](expert_input)
            expert_loss = tf.reduce_mean(tf.square(train_output - expert_output), axis=-1)

        # Compute the gradients
        expert_gradient = tape.gradient(expert_loss, experts[i].trainable_variables)
        # Clip gradients for expert models
        expert_gradient = [tf.clip_by_value(grad, -1.0, 1.0) for grad in expert_gradient]

        # Update the variables
        optimizer.apply_gradients(zip(expert_gradient, experts[i].trainable_variables))
    
    current_learning_rate = scheduler(iteration, optimizer.learning_rate.numpy())
    optimizer.learning_rate.assign(current_learning_rate)

    gating_input = train_input

    with tf.GradientTape() as tape:
        # Watch the trainable variables of the gating model
        tape.watch(gating_model.trainable_variables)

        # Define the gating model and calculate the gating_loss
        gating_output = gating_model(gating_input)
        gating_loss = moe_loss(tf.constant(train_output, dtype=tf.float32), moe_model(train_input), gating_output)


    # Compute the gradients
    gating_gradient = tape.gradient(gating_loss, gating_model.trainable_variables)
    # Clip gradients for the gating model
    gating_gradient = [tf.clip_by_value(grad, -1.0, 1.0) for grad in gating_gradient]

    # Update the variables
    optimizer.apply_gradients(zip(gating_gradient, gating_model.trainable_variables))

    # Evaluate the performance of the MoE model on the training set
    train_loss = moe_loss(train_output, moe_model.predict(train_input), gating_model.predict(train_input))
    
    # Check if the current loss is lower than the lowest loss so far
    if train_loss < lowest_loss:
        lowest_loss = train_loss
        # Save the current weights as the best weights
        best_weights = moe_model.get_weights()

    # add the loss to the list
    losses.append(train_loss)

    print('Iteration %d: Training loss = %.6f' % (iteration + 1, train_loss))

    # Stop training if the learning rate becomes too small
    if current_learning_rate < 1e-8:
        print('Learning rate dropped below 1e-6 after iteration %d' % iteration)
        break
    iterations.append(iteration + 1)  # Store the iteration number
    iteration += 1

# Plot the loss function values over the training iterations
plt.plot(losses)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()

moe_model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

moe_model.save('moe_models11.h5')
gating_model.save('gating_models11.h5')
for i, expert in enumerate(experts):
    expert.save(f'experts11_{i}.h5')
# Out:
# train_input shape (10000, 2)
# train_output shape (10000, 1)
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 1: Training loss = 471.877350
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 2: Training loss = 304.173187
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 3: Training loss = 192.550797
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 4: Training loss = 254.559631
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 5: Training loss = 564.187073
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 6: Training loss = 1078.284058
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 7: Training loss = 2020.668823
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 8: Training loss = 3682.041504
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 9: Training loss = 6270.101074
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 10: Training loss = 9138.083984
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 11: Training loss = 11172.621094
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 12: Training loss = 12757.916992
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 13: Training loss = 14548.157227
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 14: Training loss = 17646.265625
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 15: Training loss = 20880.923828
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 16: Training loss = 22911.177734
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 17: Training loss = 23477.861328
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 18: Training loss = 23297.583984
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 19: Training loss = 22602.906250
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 20: Training loss = 21769.375000
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 21: Training loss = 20312.171875
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 22: Training loss = 18684.476562
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 23: Training loss = 17163.791016
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 24: Training loss = 15804.451172
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 25: Training loss = 14481.711914
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 26: Training loss = 13112.997070
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 27: Training loss = 11903.545898
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 28: Training loss = 10817.960938
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 29: Training loss = 10001.430664
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 30: Training loss = 9327.139648
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 31: Training loss = 8688.140625
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 32: Training loss = 8175.777832
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 33: Training loss = 7754.660645
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 34: Training loss = 7406.420898
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 35: Training loss = 7112.130371
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 36: Training loss = 6864.506348
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 37: Training loss = 6657.854980
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 38: Training loss = 6485.732910
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 39: Training loss = 6342.958984
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 40: Training loss = 6223.897461
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 41: Training loss = 6123.494141
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 42: Training loss = 6037.349609
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 43: Training loss = 5963.634277
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 44: Training loss = 5898.507812
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 45: Training loss = 5839.529785
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 46: Training loss = 5785.463379
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 47: Training loss = 5735.191406
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 48: Training loss = 5687.192871
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 49: Training loss = 5639.344727
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 50: Training loss = 5592.844727
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 51: Training loss = 5547.500977
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 2ms/step
# Iteration 52: Training loss = 5504.279785
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 53: Training loss = 5462.357422
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 54: Training loss = 5421.920898
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 55: Training loss = 5382.301758
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 56: Training loss = 5344.127441
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 57: Training loss = 5306.843262
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 58: Training loss = 5271.073730
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 59: Training loss = 5236.159180
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 60: Training loss = 5201.424805
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 61: Training loss = 5166.363770
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 62: Training loss = 5131.255859
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 63: Training loss = 5096.351562
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 64: Training loss = 5062.265625
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 65: Training loss = 5029.567871
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 66: Training loss = 4997.965820
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 67: Training loss = 4967.391113
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 68: Training loss = 4938.103516
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 69: Training loss = 4910.111816
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 70: Training loss = 4883.527344
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 71: Training loss = 4858.353516
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 72: Training loss = 4834.603027
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 73: Training loss = 4812.248535
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 74: Training loss = 4791.206055
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 75: Training loss = 4771.470215
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 76: Training loss = 4753.011719
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 77: Training loss = 4735.681641
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 78: Training loss = 4719.525391
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 79: Training loss = 4704.480957
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 80: Training loss = 4690.489258
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 81: Training loss = 4677.493164
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 82: Training loss = 4665.429688
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 83: Training loss = 4654.247070
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 84: Training loss = 4643.880859
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 85: Training loss = 4634.276855
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 86: Training loss = 4625.362305
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 87: Training loss = 4617.116211
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 88: Training loss = 4609.483887
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 89: Training loss = 4602.441406
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 90: Training loss = 4595.928711
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 91: Training loss = 4589.917480
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 92: Training loss = 4584.367188
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 93: Training loss = 4579.243164
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 94: Training loss = 4574.520020
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 95: Training loss = 4570.162109
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 96: Training loss = 4566.145508
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 97: Training loss = 4562.449219
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 98: Training loss = 4559.034180
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 99: Training loss = 4555.890625
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 100: Training loss = 4552.993652
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 101: Training loss = 4550.332031
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 102: Training loss = 4547.883789
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 103: Training loss = 4545.628418
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 104: Training loss = 4543.558105
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 105: Training loss = 4541.654297
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 106: Training loss = 4539.903809
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 5ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 107: Training loss = 4538.292969
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 108: Training loss = 4536.815918
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 109: Training loss = 4535.463379
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 110: Training loss = 4534.218262
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 111: Training loss = 4533.075195
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 112: Training loss = 4532.025879
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 113: Training loss = 4531.063965
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 114: Training loss = 4530.180176
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 115: Training loss = 4529.370605
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 116: Training loss = 4528.628418
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 117: Training loss = 4527.947754
# 313/313 [==============================] - 0s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 118: Training loss = 4527.326660
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 119: Training loss = 4526.753418
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 120: Training loss = 4526.227051
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 121: Training loss = 4525.750488
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 122: Training loss = 4525.311035
# 313/313 [==============================] - 0s 2ms/step
# 313/313 [==============================] - 1s 3ms/step
# 313/313 [==============================] - 0s 1ms/step
# Iteration 123: Training loss = 4524.910156
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 5ms/step
# 313/313 [==============================] - 1s 2ms/step
# Iteration 124: Training loss = 4524.541016
# Learning rate dropped below 1e-6 after iteration 123
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
