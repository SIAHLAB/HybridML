# %%
import pandas as pd
import numpy as np
import math

df_vwc = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/s2vwc.csv', header = 0)[['TrendT', 'signal.detrend', 'Noise']].T.to_numpy()
df_stemp = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/S2T.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
df_T = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/T.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
df_RH = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/RH.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
#df_DP = np.load('/content/drive/Shareddrives/1st Paper/Array_eemd2_DP.npy', allow_pickle=True)
df_Rain = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/R.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
df_WS = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/WS.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()
#df_WD = np.load('/content/drive/Shareddrives/1st Paper/Array_eemd2_WD.npy', allow_pickle=True)
df_S = pd.read_csv('/content/drive/Shareddrives/1st Paper/SSA/SR.csv', header = 0)[['trend_total', 'signal.detrend', 'noise_Stage2']].T.to_numpy()

list_ = [df_vwc, df_Rain, df_stemp, df_T, df_RH,  df_WS, df_S]

# IMF = np.empty((10, 10, 10))
ssa = [[],[],[]]
# for i in list_:
#   print(i.shape)
for k in range(len(ssa)):
  for i in list_:
    ssa[k].append(i[k])


# df_vwc = pd.DataFrame(df_vwc).T
# df_vwc.columns = ['IMF1','IMF2','IMF3','IMF4','IMF5','IMF6','IMF7','IMF8','IMF9','IMF10','IMF11',
#               'IMF12','IMF13','IMF14', 'IMF15']

# df_stemp = pd.DataFrame(df_stemp).T
# df_stemp.columns = ['IMF1','IMF2','IMF3','IMF4','IMF5','IMF6','IMF7','IMF8','IMF9','IMF10','IMF11',
#               'IMF12','IMF13']

# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.4.47)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 22.5 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.2 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.0

# %%
##LSTM
import pandas as pd
import numpy as np
import math

import sklearn
import keras
import keras.backend as K
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM, CuDNNLSTM, MaxPooling1D, Conv1D, Flatten, BatchNormalization, Dropout, Input
from keras.models import Model
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping


from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from math import sqrt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from multiprocessing import cpu_count 
from joblib import Parallel 
from joblib import delayed 
from datetime import datetime

import optuna 

from sklearn.preprocessing import StandardScaler

from keras.utils import custom_object_scope
from keras.utils import get_custom_objects

from keras.layers import LSTM, RepeatVector, TimeDistributed, BatchNormalization, Dropout
from keras.initializers import GlorotUniform
from keras.activations import relu
from joblib import Parallel, delayed

import cProfile

# from warnings import catch_warnings 
# from warnings import filterwarnings

# %%
####################################################################################################
def nmse(y_true, y_pred):
    """
    Calculate the normalized mean squared error (NMSE) between y_true and y_pred.
    """
    return np.mean(np.square(y_pred - y_true)) / np.var(y_true)
####################################################################################################
def smape(y_true, y_pred):
    """
    Calculate the Symmetric Mean Absolute Percentage Error (SMAPE) between y_true and y_pred.
    """
    return np.mean(2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred))) * 100
####################################################################################################
def smase(y_true, y_pred, y_naive):
    """
    Calculate the Symmetric Mean Absolute Scaled Error (sMASE) between y_true and y_pred, relative 
    to a symmetric naive forecast y_naive.
    """
    # Calculate the symmetric naive forecast
    y_sym_naive = (y_naive.shift(1) + y_naive.shift(-1)) / 2.0
    
    # Calculate the MAPE of the forecast relative to the symmetric naive forecast
    mape_forecast = np.mean(np.abs(y_pred - y_sym_naive) / np.abs(y_true - y_sym_naive))
    
    # Calculate the MAPE of the historical data relative to the same symmetric naive forecast
    mape_historical = np.mean(np.abs(y_true - y_sym_naive.shift(1)) / np.abs(y_true - y_sym_naive))
    
    return mape_forecast / mape_historical
####################################################################################################
def nse(y_true, y_pred):
    """
    Calculate the Nash-Sutcliffe Efficiency (NSE) between y_true and y_pred.
    """
    mse = mean_squared_error(y_true, y_pred)
    rss = mse * len(y_true)
    tss = mean_absolute_error(y_true, np.mean(y_true)) ** 2 * len(y_true)
    return 1 - (rss / tss)
#####################################################################################################
def r2_keras(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# Register the custom metric function with Keras
with custom_object_scope({'r2_keras': r2_keras}):
    get_custom_objects().update({'r2_keras': r2_keras})

# %%
##Encoder/Decoder LSTM with Multivariate Input

#Splitting datasets into train/test set

def split_dataset(data):
  # split into standard weeks
  train, test = data[1:-6046], data[-6048:]
  #train, test = data[:-5817], data[-5817:-57]
  # restructure into windows of weekly data
  train = np.array(np.split(train, len(train)/144))
  test = np.array(np.split( test , len(test )/144))
  return train, test

def rmse_(actual, predicted):
    return np.sqrt(mean_squared_error(actual, predicted))

def nmse(actual, predicted):
    return mean_squared_error(actual, predicted) / np.var(actual)

def smape(actual, predicted):
    return 100 / len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted)))

def nse(actual, predicted):
    return 1 - np.sum((actual - predicted) ** 2) / np.sum((actual - np.mean(actual)) ** 2)

def r2(y_true, y_pred):
    SS_res =  np.sum(K.square(y_true - y_pred))
    SS_tot =  np.sum(K.square(y_true - np.mean(y_true)))
    return 1 - SS_res/(SS_tot + np.finfo(float).eps) 

def compute_scores(actual, predicted):
    rmse_score = rmse_(actual, predicted)
    nmse_score = nmse(actual, predicted)
    smape_score = smape(actual, predicted)
    nse_score = nse(actual, predicted)
    r2_score = r2(actual, predicted)
    return rmse_score, nmse_score, smape_score, nse_score, r2_score

def evaluate_forecasts(actual, predicted):
    # rmse_scores = [rmse_(actual[:, i],   predicted[:, i])      for i in  range(actual.shape[1])]
    # nmse_scores = [nmse(actual[:, i],    predicted[:, i])      for i in  range(actual.shape[1])]
    # smape_scores = [smape(actual[:, i],  predicted[:, i])      for i in  range(actual.shape[1])]
    # nse_scores = [nse(actual[:, i],      predicted[:, i])      for i in  range(actual.shape[1])]
    # r2_scores = [r2(actual[:,i],   predicted[:, i])      for i in  range(actual.shape[1])]
    # parallelize the loop using joblib

    rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores = zip(*Parallel(n_jobs=-1)(
    delayed(compute_scores)(actual[:, i], predicted[:, i]) for i in range(actual.shape[1])))

    overall_rmse = rmse_(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_nmse = nmse(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_smape = smape(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_nse = nse(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    overall_r2 = r2(actual, predicted.reshape(predicted.shape[0],predicted.shape[1]))
    return overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores

#####################################################################################################
#summarize scores
def summarize_scores(name, score, scores):
  s_scores = ', '.join(['%.1f' % s for s in scores])
  print('%s: [%.3f] %s' % (name, score, s_scores))

# convert history into inputs and outputs


def to_supervised(train, n_input, n_out=144):
  #flattern data
  data = train.reshape((train.shape[0]*train.shape[1], train.shape[2]))
  X, y = list(), list()
  in_start = 0
  # step over the entire history one time step at a time
  for i in range(len(data)):
    #define the end of the input sequence
    in_end = in_start + n_input
    out_end = in_end + n_out
    #ensure there is enough data
    if out_end <= len(data):
      X.append(data[in_start:in_end, :])
      y.append(data[in_end:out_end, 0])
    # move along one time step
    in_start += 1
  return np.array(X), np.array(y)
 
# #train the model LSTM-ED

def build_model(train, config, verbose):
  # Unpack config
  n_input, n_nodes, n_epochs, n_batch = config
  # prepare data
  train_x, train_y = to_supervised(train, n_input)
  # Parameters
  n_timesteps, n_features, n_outputs = train_x.shape[1], train_x.shape[2], train_y.shape[1]
  # reshape output into [samples, timesteps, features]
  train_y = train_y.reshape((train_y.shape[0], train_y.shape[1], 1))
  
  #define model
  
  # define model input
  inputs = Input(shape=(n_timesteps, n_features))
  
  # encoder layers
  encoder = CuDNNLSTM(n_nodes)(inputs)
  encoder = RepeatVector(n_outputs)(encoder)
  
  # decoder layers
  decoder = CuDNNLSTM(n_nodes, return_sequences=True)(encoder)
  decoder = TimeDistributed(Dense(n_nodes/2))(decoder)
  decoder = TimeDistributed(Dense(1))(decoder)

  # define model
  model = Model(inputs=inputs, outputs=decoder)

  model.compile(loss='mae', optimizer='adam',  metrics= ['MeanAbsoluteError', 'MeanSquaredError', 'mean_absolute_percentage_error', 'r2_keras'])
  
  # fit network
  model.fit(train_x, train_y, epochs=n_epochs, batch_size=n_batch, verbose= verbose)
  plt.plot(model.history.history['loss'])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['loss'], loc='upper right')
  plt.show()
  plt.clf()
  plt.plot(model.history.history['mean_absolute_error'])
  plt.plot(model.history.history['mean_squared_error'])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['mean_absolute_error', 'mean_squared_error'], loc='upper right')
  plt.show()
  plt.clf()
  plt.plot(model.history.history['mean_absolute_percentage_error'])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['mean_absolute_percentage_error'], loc='upper right')
  plt.show()
  plt.clf()
  plt.plot(model.history.history['r2_keras'])
  #plt.plot(model.history.history[])
  plt.title('Training Metrics')
  plt.ylabel('Value')
  plt.xlabel('Epoch')
  plt.legend(['r2_score'], loc='upper right')
  plt.show()
  return model

#forecast

def forecast(model, history, config):
  # unpack config
  n_input, _, _, _ = config
  #flattern data
  data = np.array(history)
  data = data.reshape((data.shape[0]*data.shape[1], data.shape[2]))
  #retrieve last observations for input data
  input_x = data[-n_input:, :]
  # reshape into [1, n_input, n]
  input_x = input_x.reshape((1, input_x.shape[0], input_x.shape[1]))
  #forecast the next week
  yhat = model.predict(input_x, verbose=0)
  # we only want the vector forecast
  yhat = yhat
  return yhat

#evaluate a single model

def evaluate_model(train, test, cfg, verbose):
  #fit model
  model= build_model(train, cfg, verbose)
  #test = X_scaler.transform(test)
  # history is a list of n_input data
  history = [x for x in train]
  #walk_forward validation over each week
  predictions = list()
  for i in range(len(test)):
    #predict the week
    yhat_sequence = forecast(model, history, cfg)[0]
    #store the predictions
    predictions.append(yhat_sequence)
    #get real observation an add to history for predicting the next week
    history.append(test[i, :])
  #evaluate predictions hours for each n_input
  predictions = np.array(predictions)
  #overall_rmse,overall_nmse, overall_smape, overall_nse, rmse_scores, nmse_scores, smape_scores, nse_scores
  overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores = evaluate_forecasts(test[:, :, 0], predictions)
  return overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores, predictions, model

#Repeat evaluate

def repeat_evaluate(train, test, config, verbose, n_repeats=2):
  # Convert config to a key
  key = str(config)
  # fit and evaluate the model n times
  overall_rmse,overall_nmse, overall_smape, overall_nse, overall_r2, rmse_scores, nmse_scores, smape_scores, nse_scores, r2_scores, predictions, model = evaluate_model(train, test, config, verbose)
  overall_rmse_models = [overall_rmse for _ in range(n_repeats)]
  overall_nmse_models = [overall_nmse for _ in range(n_repeats)]
  overall_smape_models = [overall_smape for _ in range(n_repeats)]
  overall_nse_models = [overall_nse for _ in range(n_repeats)]
  overall_r2_models = [overall_r2 for _ in range(n_repeats)]
  # Sumarize score
  result_rmse =  np.mean(overall_rmse_models)
  result_nmse =  np.mean(overall_nmse_models)
  result_smape = np.mean(overall_smape_models)
  result_nse =   np.mean(overall_nse_models)
  result_r2 =    np.mean(overall_r2_models)
  #print('> Model[%s] %.3f' % (key, result))
  return (key, result_rmse, result_nmse, result_smape, result_nse, result_r2), predictions

# grid_search configs

def grid_search(train, test, cfg_list, verbose):
  #evaluate configs
  pack = [repeat_evaluate(train, test, cfg, verbose) for cfg in cfg_list]
  #sort config by error, asc
  scores = [item[0] for item in pack]
  predictions = [item[1] for item in pack]
  scores.sort(key=lambda tup: tup[1])
  return scores, predictions


def model_configs():
  n_input = [200]
  n_nodes = [200]
  n_epochs = [250]
  n_batch = [10]
  configs = list()
  for i in n_input:
    for j in n_nodes:
      for k in n_epochs:
        for l in n_batch:
          cfg = [i, j, k , l]
          configs.append(cfg)
  print('Total configs: %d' % len(configs))
  return configs

# %%
# define the objective function
def objective(trial):

    # specify the hyperparameters to optimize
    n_input = trial.suggest_int('n_input', 1, 144)
    n_nodes = trial.suggest_int('n_nodes', 32, 256)
    n_epochs = trial.suggest_int('n_epochs', 10, 100)
    n_batch = trial.suggest_int('n_batch', 16, 128)
    
    # split the data into training and testing sets
    train, test = split_dataset(df_s.values)
    #train = df_s.values

    # split the training data into folds for walk-forward validation
    n_splits = 5
    fold_size = int(len(train) / n_splits)
    folds = [train[i:i+fold_size] for i in range(0, len(train), fold_size)]
    
    # build the model using the hyperparameters
    model = build_model(train, (n_input, n_nodes, n_epochs, n_batch), verbose=False)
    
    
    # train and evaluate the model using walk-forward validation
    val_losses = []
    for i in range(n_splits):
        # prepare data for this fold
        train_x, train_y = to_supervised(np.concatenate(folds[:i] + folds[i+1:]), n_input)
        val_x, val_y = to_supervised(folds[i], n_input)
        train_y = train_y.reshape((train_y.shape[0], train_y.shape[1], 1))
        val_y = val_y.reshape((val_y.shape[0], val_y.shape[1], 1))
        
        # train the model using early stopping
        es = EarlyStopping(monitor='val_loss', patience=10)
        history = model.fit(train_x, train_y, epochs=n_epochs, batch_size=n_batch, validation_data=(val_x, val_y), verbose=False, callbacks=[es])
        
        # evaluate the model on the validation set for this fold
        val_loss = history.history['val_loss'][-1]
        val_losses.append(val_loss)

        # metrics on validation set for this fold
        #al_mae = history.history['mean_absolute_error'][-1]
        #val_mse = history.history['mean_squared_error'][-1]
    
    # return the mean validation loss across all folds
    return np.mean(val_losses)

# %%
#Scores_IMF = []
dataset = pd.read_csv('/content/drive/Shareddrives/1st Paper/2nd.csv', header = 0, infer_datetime_format=True, index_col=['Date Time'])
#dataset = dataset[:-8438]
# set the base name of the file
base_filename = '/content/drive/Shareddrives/1st Paper/Performance/S2_best_model_ssa_VWC'

for m in range(0, 3):

  sc = ([0, 0, 0, 0], 0, 0, 0, 0, 0)
  print('IMF: ', m)
  data = pd.DataFrame(ssa[m]).T
  data.columns = ['S2_Top_VWC_Avg','Rain','S2_Top_Temp_Avg','Temp', 'Relative Humidity',
                 'Wind Speed', 'Solar Radiation']
  #testing = data[-8438:]
  #data = data[:-8438] 
  data = data

  # %time
  External = data[['Rain','S2_Top_Temp_Avg','Temp', 'Relative Humidity',
                 'Wind Speed', 'Solar Radiation']]
  Predicted = data[['S2_Top_VWC_Avg']]
  index = pd.DataFrame(dataset.index)
  
  scaler = StandardScaler()
  scaler.fit(External)
  print('Scale_:', scaler.scale_)
    
  var = pd.DataFrame(scaler.transform(External))

  #var = data
  df = pd.concat([index, data['S2_Top_VWC_Avg'], var], axis = 1)
  df = df.set_index('Date Time')
  df.columns = ['S2_Top_VWC_Avg','Rain','S2_Top_Temp_Avg','Temp', 'Relative Humidity',
                  'Wind Speed', 'Solar Radiation']
  df_s = df


  
  # create the study
  study = optuna.create_study(direction='minimize', storage='sqlite:///example.db')

  # start the optimization
  study.optimize(objective, n_trials=3)

  # retrieve the best hyperparameters
  best_params = study.best_params
  print('Best hyperparameters:', best_params)

  train, test = split_dataset(df.values)

  # train the model using the best hyperparameters on the entire training set
  model = build_model(train, (best_params['n_input'], best_params['n_nodes'], best_params['n_epochs'], best_params['n_batch']), verbose=True)

  # set the filename based on the unique identifier
  filename = f"{base_filename}_{m}.h5"

  # save the model to a file
  model.save(filename)
# Out:
# IMF:  0
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.68 µs
# Scale_: [0.05333779 0.75468992 0.59696625 0.90858732 0.94264763 0.89602207]
# [I 2023-03-31 02:33:45,509] A new study created in RDB with name: no-name-089908e7-aff8-481b-8dc3-162243a378e1
# [I 2023-03-31 03:04:04,971] Trial 0 finished with value: 0.2508361726999283 and parameters: {'n_input': 84, 'n_nodes': 219, 'n_epochs': 89, 'n_batch': 17}. Best is trial 0 with value: 0.2508361726999283.
# [I 2023-03-31 03:09:00,708] Trial 1 finished with value: 0.48202029466629026 and parameters: {'n_input': 89, 'n_nodes': 109, 'n_epochs': 29, 'n_batch': 59}. Best is trial 0 with value: 0.2508361726999283.
# [I 2023-03-31 03:23:40,559] Trial 2 finished with value: 0.3148982018232346 and parameters: {'n_input': 124, 'n_nodes': 207, 'n_epochs': 98, 'n_batch': 101}. Best is trial 0 with value: 0.2508361726999283.
# Best hyperparameters: {'n_batch': 17, 'n_epochs': 89, 'n_input': 84, 'n_nodes': 219}
# Epoch 1/89
# 1054/1054 [==============================] - 17s 14ms/step - loss: 0.9683 - mean_absolute_error: 0.9683 - mean_squared_error: 3.6198 - mean_absolute_percentage_error: 159.9319 - r2_keras: 0.2098
# Epoch 2/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.9099 - mean_absolute_error: 0.9099 - mean_squared_error: 3.4503 - mean_absolute_percentage_error: 151.8550 - r2_keras: 0.2510
# Epoch 3/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.8289 - mean_absolute_error: 0.8289 - mean_squared_error: 3.1537 - mean_absolute_percentage_error: 136.3085 - r2_keras: 0.3314
# Epoch 4/89
# 1054/1054 [==============================] - 16s 15ms/step - loss: 0.7733 - mean_absolute_error: 0.7733 - mean_squared_error: 2.9442 - mean_absolute_percentage_error: 134.6227 - r2_keras: 0.3843
# Epoch 5/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.6735 - mean_absolute_error: 0.6735 - mean_squared_error: 2.5268 - mean_absolute_percentage_error: 115.6018 - r2_keras: 0.4763
# Epoch 6/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.6094 - mean_absolute_error: 0.6094 - mean_squared_error: 2.2570 - mean_absolute_percentage_error: 105.2744 - r2_keras: 0.5403
# Epoch 7/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.5666 - mean_absolute_error: 0.5666 - mean_squared_error: 2.0734 - mean_absolute_percentage_error: 95.1709 - r2_keras: 0.5745
# Epoch 8/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.5388 - mean_absolute_error: 0.5388 - mean_squared_error: 1.8471 - mean_absolute_percentage_error: 95.1983 - r2_keras: 0.6161
# Epoch 9/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.4877 - mean_absolute_error: 0.4877 - mean_squared_error: 1.5652 - mean_absolute_percentage_error: 87.1051 - r2_keras: 0.6659
# Epoch 10/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.4664 - mean_absolute_error: 0.4664 - mean_squared_error: 1.4211 - mean_absolute_percentage_error: 89.4657 - r2_keras: 0.6959
# Epoch 11/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.4402 - mean_absolute_error: 0.4402 - mean_squared_error: 1.2568 - mean_absolute_percentage_error: 87.0349 - r2_keras: 0.7239
# Epoch 12/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.4120 - mean_absolute_error: 0.4120 - mean_squared_error: 1.1509 - mean_absolute_percentage_error: 80.3240 - r2_keras: 0.7476
# Epoch 13/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.3921 - mean_absolute_error: 0.3921 - mean_squared_error: 1.0343 - mean_absolute_percentage_error: 78.8054 - r2_keras: 0.7705
# Epoch 14/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.3979 - mean_absolute_error: 0.3979 - mean_squared_error: 1.0227 - mean_absolute_percentage_error: 83.2207 - r2_keras: 0.7628
# Epoch 15/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.3742 - mean_absolute_error: 0.3742 - mean_squared_error: 0.8855 - mean_absolute_percentage_error: 78.9737 - r2_keras: 0.7935
# Epoch 16/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.3514 - mean_absolute_error: 0.3514 - mean_squared_error: 0.8131 - mean_absolute_percentage_error: 74.5366 - r2_keras: 0.8113
# Epoch 17/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.3384 - mean_absolute_error: 0.3384 - mean_squared_error: 0.7555 - mean_absolute_percentage_error: 73.0801 - r2_keras: 0.8226
# Epoch 18/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.3237 - mean_absolute_error: 0.3237 - mean_squared_error: 0.6918 - mean_absolute_percentage_error: 71.8325 - r2_keras: 0.8368
# Epoch 19/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.3179 - mean_absolute_error: 0.3179 - mean_squared_error: 0.6552 - mean_absolute_percentage_error: 71.7083 - r2_keras: 0.8438
# Epoch 20/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.3035 - mean_absolute_error: 0.3035 - mean_squared_error: 0.5999 - mean_absolute_percentage_error: 68.7694 - r2_keras: 0.8532
# Epoch 21/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.3104 - mean_absolute_error: 0.3104 - mean_squared_error: 0.6165 - mean_absolute_percentage_error: 70.7642 - r2_keras: 0.8490
# Epoch 22/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2904 - mean_absolute_error: 0.2904 - mean_squared_error: 0.5585 - mean_absolute_percentage_error: 67.7721 - r2_keras: 0.8636
# Epoch 23/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2870 - mean_absolute_error: 0.2870 - mean_squared_error: 0.5410 - mean_absolute_percentage_error: 67.0304 - r2_keras: 0.8690
# Epoch 24/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2988 - mean_absolute_error: 0.2988 - mean_squared_error: 0.5740 - mean_absolute_percentage_error: 70.2562 - r2_keras: 0.8624
# Epoch 25/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2739 - mean_absolute_error: 0.2739 - mean_squared_error: 0.4962 - mean_absolute_percentage_error: 65.7863 - r2_keras: 0.8779
# Epoch 26/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2662 - mean_absolute_error: 0.2662 - mean_squared_error: 0.4764 - mean_absolute_percentage_error: 64.8121 - r2_keras: 0.8830
# Epoch 27/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2696 - mean_absolute_error: 0.2696 - mean_squared_error: 0.4839 - mean_absolute_percentage_error: 66.1259 - r2_keras: 0.8823
# Epoch 28/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2621 - mean_absolute_error: 0.2621 - mean_squared_error: 0.4537 - mean_absolute_percentage_error: 65.2550 - r2_keras: 0.8878
# Epoch 29/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2655 - mean_absolute_error: 0.2655 - mean_squared_error: 0.4540 - mean_absolute_percentage_error: 66.2999 - r2_keras: 0.8852
# Epoch 30/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2512 - mean_absolute_error: 0.2512 - mean_squared_error: 0.4239 - mean_absolute_percentage_error: 64.1225 - r2_keras: 0.8959
# Epoch 31/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2551 - mean_absolute_error: 0.2551 - mean_squared_error: 0.4333 - mean_absolute_percentage_error: 64.9058 - r2_keras: 0.8917
# Epoch 32/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2461 - mean_absolute_error: 0.2461 - mean_squared_error: 0.4072 - mean_absolute_percentage_error: 64.2297 - r2_keras: 0.8990
# Epoch 33/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2508 - mean_absolute_error: 0.2508 - mean_squared_error: 0.4247 - mean_absolute_percentage_error: 65.5907 - r2_keras: 0.8937
# Epoch 34/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2690 - mean_absolute_error: 0.2690 - mean_squared_error: 0.4894 - mean_absolute_percentage_error: 67.9467 - r2_keras: 0.8777
# Epoch 35/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2370 - mean_absolute_error: 0.2370 - mean_squared_error: 0.3830 - mean_absolute_percentage_error: 62.3630 - r2_keras: 0.9031
# Epoch 36/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2338 - mean_absolute_error: 0.2338 - mean_squared_error: 0.3732 - mean_absolute_percentage_error: 61.9907 - r2_keras: 0.9060
# Epoch 37/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2350 - mean_absolute_error: 0.2350 - mean_squared_error: 0.3847 - mean_absolute_percentage_error: 62.3266 - r2_keras: 0.9035
# Epoch 38/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2360 - mean_absolute_error: 0.2360 - mean_squared_error: 0.3852 - mean_absolute_percentage_error: 62.9722 - r2_keras: 0.9045
# Epoch 39/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - mean_squared_error: 0.3640 - mean_absolute_percentage_error: 62.1417 - r2_keras: 0.9091
# Epoch 40/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2266 - mean_absolute_error: 0.2266 - mean_squared_error: 0.3539 - mean_absolute_percentage_error: 61.6134 - r2_keras: 0.9119
# Epoch 41/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2338 - mean_absolute_error: 0.2338 - mean_squared_error: 0.3930 - mean_absolute_percentage_error: 62.7519 - r2_keras: 0.9028
# Epoch 42/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2304 - mean_absolute_error: 0.2304 - mean_squared_error: 0.3663 - mean_absolute_percentage_error: 63.8251 - r2_keras: 0.9070
# Epoch 43/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2304 - mean_absolute_error: 0.2304 - mean_squared_error: 0.3792 - mean_absolute_percentage_error: 62.9102 - r2_keras: 0.9064
# Epoch 44/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2206 - mean_absolute_error: 0.2206 - mean_squared_error: 0.3471 - mean_absolute_percentage_error: 62.4585 - r2_keras: 0.9121
# Epoch 45/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2191 - mean_absolute_error: 0.2191 - mean_squared_error: 0.3435 - mean_absolute_percentage_error: 60.6590 - r2_keras: 0.9134
# Epoch 46/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2227 - mean_absolute_error: 0.2227 - mean_squared_error: 0.3601 - mean_absolute_percentage_error: 61.2927 - r2_keras: 0.9093
# Epoch 47/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2151 - mean_absolute_error: 0.2151 - mean_squared_error: 0.3364 - mean_absolute_percentage_error: 60.4858 - r2_keras: 0.9146
# Epoch 48/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2131 - mean_absolute_error: 0.2131 - mean_squared_error: 0.3255 - mean_absolute_percentage_error: 60.3626 - r2_keras: 0.9177
# Epoch 49/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2200 - mean_absolute_error: 0.2200 - mean_squared_error: 0.3360 - mean_absolute_percentage_error: 61.8719 - r2_keras: 0.9151
# Epoch 50/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2170 - mean_absolute_error: 0.2170 - mean_squared_error: 0.3311 - mean_absolute_percentage_error: 62.0506 - r2_keras: 0.9164
# Epoch 51/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2268 - mean_absolute_error: 0.2268 - mean_squared_error: 0.3735 - mean_absolute_percentage_error: 64.4986 - r2_keras: 0.9066
# Epoch 52/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2136 - mean_absolute_error: 0.2136 - mean_squared_error: 0.3254 - mean_absolute_percentage_error: 61.5047 - r2_keras: 0.9174
# Epoch 53/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2049 - mean_absolute_error: 0.2049 - mean_squared_error: 0.2970 - mean_absolute_percentage_error: 59.8334 - r2_keras: 0.9245
# Epoch 54/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2136 - mean_absolute_error: 0.2136 - mean_squared_error: 0.3167 - mean_absolute_percentage_error: 61.3409 - r2_keras: 0.9189
# Epoch 55/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2054 - mean_absolute_error: 0.2054 - mean_squared_error: 0.2952 - mean_absolute_percentage_error: 60.2233 - r2_keras: 0.9244
# Epoch 56/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1992 - mean_absolute_error: 0.1992 - mean_squared_error: 0.2835 - mean_absolute_percentage_error: 59.1486 - r2_keras: 0.9283
# Epoch 57/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1998 - mean_absolute_error: 0.1998 - mean_squared_error: 0.2872 - mean_absolute_percentage_error: 58.9655 - r2_keras: 0.9275
# Epoch 58/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1987 - mean_absolute_error: 0.1987 - mean_squared_error: 0.2815 - mean_absolute_percentage_error: 58.8460 - r2_keras: 0.9288
# Epoch 59/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2063 - mean_absolute_error: 0.2063 - mean_squared_error: 0.3026 - mean_absolute_percentage_error: 60.4375 - r2_keras: 0.9237
# Epoch 60/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2074 - mean_absolute_error: 0.2074 - mean_squared_error: 0.3001 - mean_absolute_percentage_error: 60.7116 - r2_keras: 0.9234
# Epoch 61/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2058 - mean_absolute_error: 0.2058 - mean_squared_error: 0.2888 - mean_absolute_percentage_error: 62.2481 - r2_keras: 0.9255
# Epoch 62/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1934 - mean_absolute_error: 0.1934 - mean_squared_error: 0.2596 - mean_absolute_percentage_error: 59.0907 - r2_keras: 0.9338
# Epoch 63/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1933 - mean_absolute_error: 0.1933 - mean_squared_error: 0.2608 - mean_absolute_percentage_error: 59.1806 - r2_keras: 0.9337
# Epoch 64/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1936 - mean_absolute_error: 0.1936 - mean_squared_error: 0.2638 - mean_absolute_percentage_error: 59.0745 - r2_keras: 0.9319
# Epoch 65/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1916 - mean_absolute_error: 0.1916 - mean_squared_error: 0.2568 - mean_absolute_percentage_error: 59.0119 - r2_keras: 0.9347
# Epoch 66/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1925 - mean_absolute_error: 0.1925 - mean_squared_error: 0.2651 - mean_absolute_percentage_error: 58.8426 - r2_keras: 0.9325
# Epoch 67/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1922 - mean_absolute_error: 0.1922 - mean_squared_error: 0.2573 - mean_absolute_percentage_error: 58.8022 - r2_keras: 0.9344
# Epoch 68/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.2017 - mean_absolute_error: 0.2017 - mean_squared_error: 0.2727 - mean_absolute_percentage_error: 61.6604 - r2_keras: 0.9300
# Epoch 69/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2140 - mean_absolute_error: 0.2140 - mean_squared_error: 0.3142 - mean_absolute_percentage_error: 63.5189 - r2_keras: 0.9181
# Epoch 70/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.2228 - mean_absolute_error: 0.2228 - mean_squared_error: 0.2827 - mean_absolute_percentage_error: 62.8743 - r2_keras: 0.9257
# Epoch 71/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1938 - mean_absolute_error: 0.1938 - mean_squared_error: 0.2453 - mean_absolute_percentage_error: 59.0789 - r2_keras: 0.9374
# Epoch 72/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1874 - mean_absolute_error: 0.1874 - mean_squared_error: 0.2340 - mean_absolute_percentage_error: 58.1595 - r2_keras: 0.9399
# Epoch 73/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1869 - mean_absolute_error: 0.1869 - mean_squared_error: 0.2365 - mean_absolute_percentage_error: 58.0824 - r2_keras: 0.9396
# Epoch 74/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1860 - mean_absolute_error: 0.1860 - mean_squared_error: 0.2365 - mean_absolute_percentage_error: 57.8968 - r2_keras: 0.9396
# Epoch 75/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1874 - mean_absolute_error: 0.1874 - mean_squared_error: 0.2475 - mean_absolute_percentage_error: 57.8499 - r2_keras: 0.9380
# Epoch 76/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1886 - mean_absolute_error: 0.1886 - mean_squared_error: 0.2525 - mean_absolute_percentage_error: 58.2248 - r2_keras: 0.9349
# Epoch 77/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1866 - mean_absolute_error: 0.1866 - mean_squared_error: 0.2445 - mean_absolute_percentage_error: 58.2241 - r2_keras: 0.9370
# Epoch 78/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1846 - mean_absolute_error: 0.1846 - mean_squared_error: 0.2408 - mean_absolute_percentage_error: 57.8846 - r2_keras: 0.9385
# Epoch 79/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1860 - mean_absolute_error: 0.1860 - mean_squared_error: 0.2394 - mean_absolute_percentage_error: 57.8555 - r2_keras: 0.9381
# Epoch 80/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1837 - mean_absolute_error: 0.1837 - mean_squared_error: 0.2458 - mean_absolute_percentage_error: 57.8389 - r2_keras: 0.9365
# Epoch 81/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1840 - mean_absolute_error: 0.1840 - mean_squared_error: 0.2497 - mean_absolute_percentage_error: 57.5144 - r2_keras: 0.9365
# Epoch 82/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1827 - mean_absolute_error: 0.1827 - mean_squared_error: 0.2357 - mean_absolute_percentage_error: 57.8567 - r2_keras: 0.9397
# Epoch 83/89
# 1054/1054 [==============================] - 14s 14ms/step - loss: 0.1841 - mean_absolute_error: 0.1841 - mean_squared_error: 0.2416 - mean_absolute_percentage_error: 58.7782 - r2_keras: 0.9380
# Epoch 84/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1839 - mean_absolute_error: 0.1839 - mean_squared_error: 0.2360 - mean_absolute_percentage_error: 58.9499 - r2_keras: 0.9394
# Epoch 85/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1792 - mean_absolute_error: 0.1792 - mean_squared_error: 0.2265 - mean_absolute_percentage_error: 57.5222 - r2_keras: 0.9426
# Epoch 86/89
# 1054/1054 [==============================] - 15s 15ms/step - loss: 0.1827 - mean_absolute_error: 0.1827 - mean_squared_error: 0.2329 - mean_absolute_percentage_error: 57.6840 - r2_keras: 0.9396
# Epoch 87/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1805 - mean_absolute_error: 0.1805 - mean_squared_error: 0.2287 - mean_absolute_percentage_error: 57.3560 - r2_keras: 0.9414
# Epoch 88/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1876 - mean_absolute_error: 0.1876 - mean_squared_error: 0.2474 - mean_absolute_percentage_error: 59.6328 - r2_keras: 0.9357
# Epoch 89/89
# 1054/1054 [==============================] - 15s 14ms/step - loss: 0.1786 - mean_absolute_error: 0.1786 - mean_squared_error: 0.2121 - mean_absolute_percentage_error: 58.3502 - r2_keras: 0.9452
# IMF:  1
# [I 2023-03-31 03:46:24,658] A new study created in RDB with name: no-name-189b5fc4-a8aa-479e-b5a8-130cde98d2bb
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.48 µs
# Scale_: [0.10577994 0.71452845 0.79257864 0.79027109 0.79057888 0.16606185]
# [I 2023-03-31 04:09:04,646] Trial 0 finished with value: 0.23832248896360397 and parameters: {'n_input': 132, 'n_nodes': 219, 'n_epochs': 84, 'n_batch': 36}. Best is trial 0 with value: 0.23832248896360397.
# [I 2023-03-31 04:14:46,226] Trial 1 finished with value: 0.5175377905368805 and parameters: {'n_input': 119, 'n_nodes': 182, 'n_epochs': 26, 'n_batch': 119}. Best is trial 0 with value: 0.23832248896360397.
# [I 2023-03-31 04:31:06,446] Trial 2 finished with value: 0.31255837678909304 and parameters: {'n_input': 35, 'n_nodes': 198, 'n_epochs': 54, 'n_batch': 24}. Best is trial 0 with value: 0.23832248896360397.
# Best hyperparameters: {'n_batch': 36, 'n_epochs': 84, 'n_input': 132, 'n_nodes': 219}
# Epoch 1/84
# 497/497 [==============================] - 13s 20ms/step - loss: 1.0288 - mean_absolute_error: 1.0288 - mean_squared_error: 3.1646 - mean_absolute_percentage_error: 279.9677 - r2_keras: 0.1000
# Epoch 2/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.8985 - mean_absolute_error: 0.8985 - mean_squared_error: 2.8581 - mean_absolute_percentage_error: 243.8548 - r2_keras: 0.2051
# Epoch 3/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.8699 - mean_absolute_error: 0.8699 - mean_squared_error: 2.7422 - mean_absolute_percentage_error: 227.4147 - r2_keras: 0.2347
# Epoch 4/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.7745 - mean_absolute_error: 0.7745 - mean_squared_error: 2.5157 - mean_absolute_percentage_error: 201.5777 - r2_keras: 0.3054
# Epoch 5/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.6929 - mean_absolute_error: 0.6929 - mean_squared_error: 2.3408 - mean_absolute_percentage_error: 179.3294 - r2_keras: 0.3627
# Epoch 6/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.6186 - mean_absolute_error: 0.6186 - mean_squared_error: 2.1458 - mean_absolute_percentage_error: 156.4911 - r2_keras: 0.4192
# Epoch 7/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.5676 - mean_absolute_error: 0.5676 - mean_squared_error: 1.9235 - mean_absolute_percentage_error: 127.4261 - r2_keras: 0.4813
# Epoch 8/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.5304 - mean_absolute_error: 0.5304 - mean_squared_error: 1.7349 - mean_absolute_percentage_error: 111.2050 - r2_keras: 0.5298
# Epoch 9/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.4839 - mean_absolute_error: 0.4839 - mean_squared_error: 1.5054 - mean_absolute_percentage_error: 103.2860 - r2_keras: 0.5869
# Epoch 10/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.4689 - mean_absolute_error: 0.4689 - mean_squared_error: 1.3465 - mean_absolute_percentage_error: 90.2865 - r2_keras: 0.6257
# Epoch 11/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.4507 - mean_absolute_error: 0.4507 - mean_squared_error: 1.2246 - mean_absolute_percentage_error: 86.4905 - r2_keras: 0.6538
# Epoch 12/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.4138 - mean_absolute_error: 0.4138 - mean_squared_error: 1.0622 - mean_absolute_percentage_error: 75.9413 - r2_keras: 0.6981
# Epoch 13/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.3853 - mean_absolute_error: 0.3853 - mean_squared_error: 0.8966 - mean_absolute_percentage_error: 65.7089 - r2_keras: 0.7389
# Epoch 14/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.3736 - mean_absolute_error: 0.3736 - mean_squared_error: 0.8623 - mean_absolute_percentage_error: 66.0785 - r2_keras: 0.7485
# Epoch 15/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.3559 - mean_absolute_error: 0.3559 - mean_squared_error: 0.7715 - mean_absolute_percentage_error: 61.7717 - r2_keras: 0.7730
# Epoch 16/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.3435 - mean_absolute_error: 0.3435 - mean_squared_error: 0.7245 - mean_absolute_percentage_error: 56.1870 - r2_keras: 0.7849
# Epoch 17/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.3293 - mean_absolute_error: 0.3293 - mean_squared_error: 0.6871 - mean_absolute_percentage_error: 53.7700 - r2_keras: 0.7943
# Epoch 18/84
# 497/497 [==============================] - 10s 21ms/step - loss: 0.3136 - mean_absolute_error: 0.3136 - mean_squared_error: 0.6130 - mean_absolute_percentage_error: 49.3877 - r2_keras: 0.8169
# Epoch 19/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.3057 - mean_absolute_error: 0.3057 - mean_squared_error: 0.5937 - mean_absolute_percentage_error: 48.5197 - r2_keras: 0.8218
# Epoch 20/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.3050 - mean_absolute_error: 0.3050 - mean_squared_error: 0.5751 - mean_absolute_percentage_error: 50.3421 - r2_keras: 0.8259
# Epoch 21/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2944 - mean_absolute_error: 0.2944 - mean_squared_error: 0.5467 - mean_absolute_percentage_error: 45.4359 - r2_keras: 0.8363
# Epoch 22/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2858 - mean_absolute_error: 0.2858 - mean_squared_error: 0.5218 - mean_absolute_percentage_error: 45.2932 - r2_keras: 0.8440
# Epoch 23/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2828 - mean_absolute_error: 0.2828 - mean_squared_error: 0.5097 - mean_absolute_percentage_error: 42.8280 - r2_keras: 0.8463
# Epoch 24/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2770 - mean_absolute_error: 0.2770 - mean_squared_error: 0.5029 - mean_absolute_percentage_error: 42.9679 - r2_keras: 0.8476
# Epoch 25/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2688 - mean_absolute_error: 0.2688 - mean_squared_error: 0.4674 - mean_absolute_percentage_error: 40.2426 - r2_keras: 0.8605
# Epoch 26/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2605 - mean_absolute_error: 0.2605 - mean_squared_error: 0.4383 - mean_absolute_percentage_error: 39.1314 - r2_keras: 0.8670
# Epoch 27/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2704 - mean_absolute_error: 0.2704 - mean_squared_error: 0.4639 - mean_absolute_percentage_error: 42.0035 - r2_keras: 0.8594
# Epoch 28/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2520 - mean_absolute_error: 0.2520 - mean_squared_error: 0.4183 - mean_absolute_percentage_error: 37.6878 - r2_keras: 0.8739
# Epoch 29/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2478 - mean_absolute_error: 0.2478 - mean_squared_error: 0.4096 - mean_absolute_percentage_error: 36.8505 - r2_keras: 0.8763
# Epoch 30/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2448 - mean_absolute_error: 0.2448 - mean_squared_error: 0.3880 - mean_absolute_percentage_error: 35.8173 - r2_keras: 0.8813
# Epoch 31/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2453 - mean_absolute_error: 0.2453 - mean_squared_error: 0.4049 - mean_absolute_percentage_error: 36.1443 - r2_keras: 0.8766
# Epoch 32/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2483 - mean_absolute_error: 0.2483 - mean_squared_error: 0.4031 - mean_absolute_percentage_error: 41.6156 - r2_keras: 0.8758
# Epoch 33/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2339 - mean_absolute_error: 0.2339 - mean_squared_error: 0.3617 - mean_absolute_percentage_error: 34.2721 - r2_keras: 0.8884
# Epoch 34/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2317 - mean_absolute_error: 0.2317 - mean_squared_error: 0.3602 - mean_absolute_percentage_error: 33.5642 - r2_keras: 0.8896
# Epoch 35/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2346 - mean_absolute_error: 0.2346 - mean_squared_error: 0.3777 - mean_absolute_percentage_error: 32.9764 - r2_keras: 0.8851
# Epoch 36/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2248 - mean_absolute_error: 0.2248 - mean_squared_error: 0.3388 - mean_absolute_percentage_error: 31.6359 - r2_keras: 0.8966
# Epoch 37/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2234 - mean_absolute_error: 0.2234 - mean_squared_error: 0.3375 - mean_absolute_percentage_error: 29.7861 - r2_keras: 0.8972
# Epoch 38/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2235 - mean_absolute_error: 0.2235 - mean_squared_error: 0.3474 - mean_absolute_percentage_error: 31.9653 - r2_keras: 0.8939
# Epoch 39/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2203 - mean_absolute_error: 0.2203 - mean_squared_error: 0.3263 - mean_absolute_percentage_error: 31.4125 - r2_keras: 0.9005
# Epoch 40/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2293 - mean_absolute_error: 0.2293 - mean_squared_error: 0.3558 - mean_absolute_percentage_error: 32.2608 - r2_keras: 0.8915
# Epoch 41/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2217 - mean_absolute_error: 0.2217 - mean_squared_error: 0.3321 - mean_absolute_percentage_error: 31.6357 - r2_keras: 0.8985
# Epoch 42/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2156 - mean_absolute_error: 0.2156 - mean_squared_error: 0.3103 - mean_absolute_percentage_error: 29.9214 - r2_keras: 0.9044
# Epoch 43/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2127 - mean_absolute_error: 0.2127 - mean_squared_error: 0.3108 - mean_absolute_percentage_error: 29.3206 - r2_keras: 0.9051
# Epoch 44/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2123 - mean_absolute_error: 0.2123 - mean_squared_error: 0.3125 - mean_absolute_percentage_error: 31.5663 - r2_keras: 0.9034
# Epoch 45/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2115 - mean_absolute_error: 0.2115 - mean_squared_error: 0.3107 - mean_absolute_percentage_error: 30.6638 - r2_keras: 0.9061
# Epoch 46/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2143 - mean_absolute_error: 0.2143 - mean_squared_error: 0.3176 - mean_absolute_percentage_error: 30.8993 - r2_keras: 0.9040
# Epoch 47/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2100 - mean_absolute_error: 0.2100 - mean_squared_error: 0.3037 - mean_absolute_percentage_error: 30.9005 - r2_keras: 0.9068
# Epoch 48/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2074 - mean_absolute_error: 0.2074 - mean_squared_error: 0.2924 - mean_absolute_percentage_error: 28.8411 - r2_keras: 0.9105
# Epoch 49/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2099 - mean_absolute_error: 0.2099 - mean_squared_error: 0.2986 - mean_absolute_percentage_error: 29.2059 - r2_keras: 0.9091
# Epoch 50/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2056 - mean_absolute_error: 0.2056 - mean_squared_error: 0.2929 - mean_absolute_percentage_error: 28.7491 - r2_keras: 0.9104
# Epoch 51/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2024 - mean_absolute_error: 0.2024 - mean_squared_error: 0.2868 - mean_absolute_percentage_error: 29.2217 - r2_keras: 0.9117
# Epoch 52/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2012 - mean_absolute_error: 0.2012 - mean_squared_error: 0.2836 - mean_absolute_percentage_error: 27.5481 - r2_keras: 0.9137
# Epoch 53/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.2053 - mean_absolute_error: 0.2053 - mean_squared_error: 0.2947 - mean_absolute_percentage_error: 28.5485 - r2_keras: 0.9089
# Epoch 54/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1978 - mean_absolute_error: 0.1978 - mean_squared_error: 0.2723 - mean_absolute_percentage_error: 26.9936 - r2_keras: 0.9170
# Epoch 55/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1966 - mean_absolute_error: 0.1966 - mean_squared_error: 0.2649 - mean_absolute_percentage_error: 27.9890 - r2_keras: 0.9180
# Epoch 56/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1958 - mean_absolute_error: 0.1958 - mean_squared_error: 0.2652 - mean_absolute_percentage_error: 27.9177 - r2_keras: 0.9175
# Epoch 57/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1956 - mean_absolute_error: 0.1956 - mean_squared_error: 0.2680 - mean_absolute_percentage_error: 26.9797 - r2_keras: 0.9172
# Epoch 58/84
# 497/497 [==============================] - 11s 21ms/step - loss: 0.1963 - mean_absolute_error: 0.1963 - mean_squared_error: 0.2725 - mean_absolute_percentage_error: 27.1491 - r2_keras: 0.9162
# Epoch 59/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1953 - mean_absolute_error: 0.1953 - mean_squared_error: 0.2629 - mean_absolute_percentage_error: 26.7450 - r2_keras: 0.9192
# Epoch 60/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1964 - mean_absolute_error: 0.1964 - mean_squared_error: 0.2716 - mean_absolute_percentage_error: 27.1903 - r2_keras: 0.9167
# Epoch 61/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1959 - mean_absolute_error: 0.1959 - mean_squared_error: 0.2689 - mean_absolute_percentage_error: 30.6441 - r2_keras: 0.9172
# Epoch 62/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1958 - mean_absolute_error: 0.1958 - mean_squared_error: 0.2631 - mean_absolute_percentage_error: 26.5072 - r2_keras: 0.9195
# Epoch 63/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1936 - mean_absolute_error: 0.1936 - mean_squared_error: 0.2626 - mean_absolute_percentage_error: 26.9699 - r2_keras: 0.9187
# Epoch 64/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1906 - mean_absolute_error: 0.1906 - mean_squared_error: 0.2480 - mean_absolute_percentage_error: 26.3835 - r2_keras: 0.9240
# Epoch 65/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1883 - mean_absolute_error: 0.1883 - mean_squared_error: 0.2461 - mean_absolute_percentage_error: 25.5033 - r2_keras: 0.9240
# Epoch 66/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - mean_squared_error: 0.2381 - mean_absolute_percentage_error: 24.9988 - r2_keras: 0.9260
# Epoch 67/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1871 - mean_absolute_error: 0.1871 - mean_squared_error: 0.2420 - mean_absolute_percentage_error: 24.7355 - r2_keras: 0.9258
# Epoch 68/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1896 - mean_absolute_error: 0.1896 - mean_squared_error: 0.2532 - mean_absolute_percentage_error: 26.6209 - r2_keras: 0.9214
# Epoch 69/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1880 - mean_absolute_error: 0.1880 - mean_squared_error: 0.2520 - mean_absolute_percentage_error: 25.8971 - r2_keras: 0.9222
# Epoch 70/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1849 - mean_absolute_error: 0.1849 - mean_squared_error: 0.2362 - mean_absolute_percentage_error: 24.9309 - r2_keras: 0.9270
# Epoch 71/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1872 - mean_absolute_error: 0.1872 - mean_squared_error: 0.2455 - mean_absolute_percentage_error: 25.8190 - r2_keras: 0.9252
# Epoch 72/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1847 - mean_absolute_error: 0.1847 - mean_squared_error: 0.2369 - mean_absolute_percentage_error: 24.9166 - r2_keras: 0.9274
# Epoch 73/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1843 - mean_absolute_error: 0.1843 - mean_squared_error: 0.2416 - mean_absolute_percentage_error: 25.2418 - r2_keras: 0.9260
# Epoch 74/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1819 - mean_absolute_error: 0.1819 - mean_squared_error: 0.2298 - mean_absolute_percentage_error: 24.4376 - r2_keras: 0.9286
# Epoch 75/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1825 - mean_absolute_error: 0.1825 - mean_squared_error: 0.2315 - mean_absolute_percentage_error: 24.3216 - r2_keras: 0.9282
# Epoch 76/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1811 - mean_absolute_error: 0.1811 - mean_squared_error: 0.2311 - mean_absolute_percentage_error: 24.0011 - r2_keras: 0.9285
# Epoch 77/84
# 497/497 [==============================] - 10s 21ms/step - loss: 0.1862 - mean_absolute_error: 0.1862 - mean_squared_error: 0.2513 - mean_absolute_percentage_error: 25.5106 - r2_keras: 0.9222
# Epoch 78/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1800 - mean_absolute_error: 0.1800 - mean_squared_error: 0.2254 - mean_absolute_percentage_error: 23.7746 - r2_keras: 0.9302
# Epoch 79/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1819 - mean_absolute_error: 0.1819 - mean_squared_error: 0.2366 - mean_absolute_percentage_error: 24.4292 - r2_keras: 0.9268
# Epoch 80/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1811 - mean_absolute_error: 0.1811 - mean_squared_error: 0.2296 - mean_absolute_percentage_error: 24.7847 - r2_keras: 0.9289
# Epoch 81/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1864 - mean_absolute_error: 0.1864 - mean_squared_error: 0.2359 - mean_absolute_percentage_error: 26.8046 - r2_keras: 0.9270
# Epoch 82/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1799 - mean_absolute_error: 0.1799 - mean_squared_error: 0.2239 - mean_absolute_percentage_error: 24.2184 - r2_keras: 0.9301
# Epoch 83/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1771 - mean_absolute_error: 0.1771 - mean_squared_error: 0.2148 - mean_absolute_percentage_error: 22.9939 - r2_keras: 0.9327
# Epoch 84/84
# 497/497 [==============================] - 10s 20ms/step - loss: 0.1754 - mean_absolute_error: 0.1754 - mean_squared_error: 0.2109 - mean_absolute_percentage_error: 22.3746 - r2_keras: 0.9338
# IMF:  2
# [I 2023-03-31 04:45:32,294] A new study created in RDB with name: no-name-d480c6c7-ffa7-4511-9f9e-6e3c28b9db45
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.82 µs
# Scale_: [0.99452068 0.08244896 0.0603335  0.74152791 0.73623446 0.45504398]
# [I 2023-03-31 04:49:38,750] Trial 0 finished with value: 0.4454914152622223 and parameters: {'n_input': 108, 'n_nodes': 127, 'n_epochs': 15, 'n_batch': 76}. Best is trial 0 with value: 0.4454914152622223.
# [I 2023-03-31 04:56:59,121] Trial 1 finished with value: 0.39499971866607664 and parameters: {'n_input': 136, 'n_nodes': 195, 'n_epochs': 12, 'n_batch': 69}. Best is trial 1 with value: 0.39499971866607664.
# [I 2023-03-31 05:11:10,263] Trial 2 finished with value: 0.27854145467281344 and parameters: {'n_input': 87, 'n_nodes': 205, 'n_epochs': 50, 'n_batch': 39}. Best is trial 2 with value: 0.27854145467281344.
# Best hyperparameters: {'n_batch': 39, 'n_epochs': 50, 'n_input': 87, 'n_nodes': 205}
# Epoch 1/50
# 460/460 [==============================] - 11s 18ms/step - loss: 0.9599 - mean_absolute_error: 0.9599 - mean_squared_error: 3.1787 - mean_absolute_percentage_error: 16.6719 - r2_keras: -0.0365
# Epoch 2/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.8503 - mean_absolute_error: 0.8503 - mean_squared_error: 2.8504 - mean_absolute_percentage_error: 14.5843 - r2_keras: 0.0909
# Epoch 3/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.7533 - mean_absolute_error: 0.7533 - mean_squared_error: 2.5765 - mean_absolute_percentage_error: 12.8183 - r2_keras: 0.1849
# Epoch 4/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.6793 - mean_absolute_error: 0.6793 - mean_squared_error: 2.3610 - mean_absolute_percentage_error: 11.4494 - r2_keras: 0.2601
# Epoch 5/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.6099 - mean_absolute_error: 0.6099 - mean_squared_error: 2.1179 - mean_absolute_percentage_error: 10.1879 - r2_keras: 0.3411
# Epoch 6/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.5531 - mean_absolute_error: 0.5531 - mean_squared_error: 1.8250 - mean_absolute_percentage_error: 9.2464 - r2_keras: 0.4279
# Epoch 7/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.5085 - mean_absolute_error: 0.5085 - mean_squared_error: 1.5227 - mean_absolute_percentage_error: 8.5813 - r2_keras: 0.5082
# Epoch 8/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.4736 - mean_absolute_error: 0.4736 - mean_squared_error: 1.3339 - mean_absolute_percentage_error: 8.0056 - r2_keras: 0.5634
# Epoch 9/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.4396 - mean_absolute_error: 0.4396 - mean_squared_error: 1.1995 - mean_absolute_percentage_error: 7.4643 - r2_keras: 0.6079
# Epoch 10/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.4135 - mean_absolute_error: 0.4135 - mean_squared_error: 1.0372 - mean_absolute_percentage_error: 7.0569 - r2_keras: 0.6487
# Epoch 11/50
# 460/460 [==============================] - 9s 19ms/step - loss: 0.3898 - mean_absolute_error: 0.3898 - mean_squared_error: 0.9058 - mean_absolute_percentage_error: 6.7208 - r2_keras: 0.6919
# Epoch 12/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.3789 - mean_absolute_error: 0.3789 - mean_squared_error: 0.8815 - mean_absolute_percentage_error: 6.5502 - r2_keras: 0.7014
# Epoch 13/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.3675 - mean_absolute_error: 0.3675 - mean_squared_error: 0.8561 - mean_absolute_percentage_error: 6.3654 - r2_keras: 0.7147
# Epoch 14/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.3529 - mean_absolute_error: 0.3529 - mean_squared_error: 0.7565 - mean_absolute_percentage_error: 6.1826 - r2_keras: 0.7417
# Epoch 15/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.3433 - mean_absolute_error: 0.3433 - mean_squared_error: 0.7046 - mean_absolute_percentage_error: 6.0530 - r2_keras: 0.7562
# Epoch 16/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.3333 - mean_absolute_error: 0.3333 - mean_squared_error: 0.6740 - mean_absolute_percentage_error: 5.9058 - r2_keras: 0.7657
# Epoch 17/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.3243 - mean_absolute_error: 0.3243 - mean_squared_error: 0.6402 - mean_absolute_percentage_error: 5.7793 - r2_keras: 0.7774
# Epoch 18/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.3175 - mean_absolute_error: 0.3175 - mean_squared_error: 0.6318 - mean_absolute_percentage_error: 5.6535 - r2_keras: 0.7850
# Epoch 19/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.3062 - mean_absolute_error: 0.3062 - mean_squared_error: 0.5794 - mean_absolute_percentage_error: 5.5041 - r2_keras: 0.7982
# Epoch 20/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2966 - mean_absolute_error: 0.2966 - mean_squared_error: 0.5443 - mean_absolute_percentage_error: 5.3434 - r2_keras: 0.8085
# Epoch 21/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2935 - mean_absolute_error: 0.2935 - mean_squared_error: 0.5296 - mean_absolute_percentage_error: 5.3070 - r2_keras: 0.8129
# Epoch 22/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2923 - mean_absolute_error: 0.2923 - mean_squared_error: 0.5321 - mean_absolute_percentage_error: 5.2778 - r2_keras: 0.8161
# Epoch 23/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2827 - mean_absolute_error: 0.2827 - mean_squared_error: 0.5004 - mean_absolute_percentage_error: 5.1386 - r2_keras: 0.8246
# Epoch 24/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2795 - mean_absolute_error: 0.2795 - mean_squared_error: 0.4932 - mean_absolute_percentage_error: 5.0721 - r2_keras: 0.8278
# Epoch 25/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2752 - mean_absolute_error: 0.2752 - mean_squared_error: 0.4884 - mean_absolute_percentage_error: 5.0098 - r2_keras: 0.8297
# Epoch 26/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2748 - mean_absolute_error: 0.2748 - mean_squared_error: 0.4803 - mean_absolute_percentage_error: 5.0240 - r2_keras: 0.8313
# Epoch 27/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2744 - mean_absolute_error: 0.2744 - mean_squared_error: 0.4745 - mean_absolute_percentage_error: 5.0295 - r2_keras: 0.8329
# Epoch 28/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2619 - mean_absolute_error: 0.2619 - mean_squared_error: 0.4336 - mean_absolute_percentage_error: 4.8288 - r2_keras: 0.8487
# Epoch 29/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.2605 - mean_absolute_error: 0.2605 - mean_squared_error: 0.4321 - mean_absolute_percentage_error: 4.8006 - r2_keras: 0.8480
# Epoch 30/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2547 - mean_absolute_error: 0.2547 - mean_squared_error: 0.4099 - mean_absolute_percentage_error: 4.7160 - r2_keras: 0.8554
# Epoch 31/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.2552 - mean_absolute_error: 0.2552 - mean_squared_error: 0.4143 - mean_absolute_percentage_error: 4.7331 - r2_keras: 0.8563
# Epoch 32/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2462 - mean_absolute_error: 0.2462 - mean_squared_error: 0.3880 - mean_absolute_percentage_error: 4.5787 - r2_keras: 0.8620
# Epoch 33/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.2485 - mean_absolute_error: 0.2485 - mean_squared_error: 0.4027 - mean_absolute_percentage_error: 4.6197 - r2_keras: 0.8579
# Epoch 34/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2479 - mean_absolute_error: 0.2479 - mean_squared_error: 0.3948 - mean_absolute_percentage_error: 4.6284 - r2_keras: 0.8605
# Epoch 35/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.2398 - mean_absolute_error: 0.2398 - mean_squared_error: 0.3691 - mean_absolute_percentage_error: 4.4955 - r2_keras: 0.8693
# Epoch 36/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2377 - mean_absolute_error: 0.2377 - mean_squared_error: 0.3679 - mean_absolute_percentage_error: 4.4625 - r2_keras: 0.8706
# Epoch 37/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2361 - mean_absolute_error: 0.2361 - mean_squared_error: 0.3585 - mean_absolute_percentage_error: 4.4361 - r2_keras: 0.8738
# Epoch 38/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2307 - mean_absolute_error: 0.2307 - mean_squared_error: 0.3435 - mean_absolute_percentage_error: 4.3541 - r2_keras: 0.8778
# Epoch 39/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2316 - mean_absolute_error: 0.2316 - mean_squared_error: 0.3502 - mean_absolute_percentage_error: 4.3638 - r2_keras: 0.8762
# Epoch 40/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2297 - mean_absolute_error: 0.2297 - mean_squared_error: 0.3405 - mean_absolute_percentage_error: 4.3421 - r2_keras: 0.8807
# Epoch 41/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2262 - mean_absolute_error: 0.2262 - mean_squared_error: 0.3354 - mean_absolute_percentage_error: 4.2869 - r2_keras: 0.8806
# Epoch 42/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.2265 - mean_absolute_error: 0.2265 - mean_squared_error: 0.3381 - mean_absolute_percentage_error: 4.2896 - r2_keras: 0.8802
# Epoch 43/50
# 460/460 [==============================] - 9s 19ms/step - loss: 0.2233 - mean_absolute_error: 0.2233 - mean_squared_error: 0.3290 - mean_absolute_percentage_error: 4.2338 - r2_keras: 0.8845
# Epoch 44/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2180 - mean_absolute_error: 0.2180 - mean_squared_error: 0.3119 - mean_absolute_percentage_error: 4.1659 - r2_keras: 0.8893
# Epoch 45/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2163 - mean_absolute_error: 0.2163 - mean_squared_error: 0.3029 - mean_absolute_percentage_error: 4.1272 - r2_keras: 0.8939
# Epoch 46/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2180 - mean_absolute_error: 0.2180 - mean_squared_error: 0.3164 - mean_absolute_percentage_error: 4.1536 - r2_keras: 0.8874
# Epoch 47/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2133 - mean_absolute_error: 0.2133 - mean_squared_error: 0.2990 - mean_absolute_percentage_error: 4.0820 - r2_keras: 0.8944
# Epoch 48/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.2174 - mean_absolute_error: 0.2174 - mean_squared_error: 0.3187 - mean_absolute_percentage_error: 4.1485 - r2_keras: 0.8871
# Epoch 49/50
# 460/460 [==============================] - 8s 18ms/step - loss: 0.2115 - mean_absolute_error: 0.2115 - mean_squared_error: 0.3001 - mean_absolute_percentage_error: 4.0500 - r2_keras: 0.8944
# Epoch 50/50
# 460/460 [==============================] - 8s 17ms/step - loss: 0.2100 - mean_absolute_error: 0.2100 - mean_squared_error: 0.2916 - mean_absolute_percentage_error: 4.0233 - r2_keras: 0.8969

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
